# %%
import pandas as pd
import re
import unicodedata

def enlever_accents(text):
    return ''.join(
        c for c in unicodedata.normalize('NFD', str(text))
        if unicodedata.category(c) != 'Mn'
    )

def nettoyer_texte(text):
    return enlever_accents(text.lower())

def nettoyer_colonnes(cols):
    return [nettoyer_texte(c).replace(' ', '_') for c in cols]

def detecter_sexe(titre_str):
    t = nettoyer_texte(titre_str)
    if 'masculin' in t:
        return 'Masculin'
    elif 'feminin' in t:
        return 'Feminin'
    elif 'ensemble sexes' in t or 'ensemble sexe' in t:
        return 'Ensemble'
    return '.'

def detecter_milieu(titre_str):
    t = nettoyer_texte(titre_str)
    if 'non communal' in t:
        return 'NC'
    elif 'communal' in t:
        return 'C'
    elif 'ensemble milieux' in t or 'ensemble milieu' in t:
        return 'Ensemble'
    return '.'

def detecter_unite(titre_str):
    t = nettoyer_texte(titre_str)
    if '%' in titre_str or 'pourcentage' in t:
        return '%'
    elif 'nombre' in t or 'effectif' in t:
        return 'effectif'
    return 'effectif'

def trouver_colonne_similaire(df, mots_cles):
    for col in df.columns:
        col_nettoyee = nettoyer_texte(col)
        if all(mot in col_nettoyee for mot in mots_cles):
            return col
    return None

fichier_excel = 'educ.xlsx'
xls = pd.ExcelFile(fichier_excel)

pattern = re.compile(r'^T72-(\d{2})$')
feuilles = [f for f in xls.sheet_names if pattern.match(f) and 55 <= int(pattern.match(f).group(1)) <= 89]

dfs_long = []

for feuille in feuilles:
    try:
        print(f"📄 Traitement de la feuille : {feuille}")
        titres = pd.read_excel(xls, sheet_name=feuille, nrows=2, header=None)
        titre_str = ' '.join(titres.astype(str).fillna('').values.flatten())

        sexe = detecter_sexe(titre_str)
        milieu = detecter_milieu(titre_str)
        unite = detecter_unite(titre_str)

        annee_match = re.search(r'\b(19\d{2}|20\d{2})\b', titre_str)
        if annee_match:
            annee = int(annee_match.group(1))
        else:
            match = pattern.match(feuille)
            annee = int("19" + match.group(1)) if match else '.'

        df = pd.read_excel(xls, sheet_name=feuille, skiprows=2)
        df.columns = nettoyer_colonnes(df.columns)

        # Recherche colonnes gouvernorat et groupe d'âge
        gouv_col = trouver_colonne_similaire(df, ['gouver'])
        groupe_age_col = trouver_colonne_similaire(df, ['groupe', 'age'])

        # Si la colonne gouvernorat n'existe pas, on la crée avec '.'
        if gouv_col is None:
            df['gouvernorat'] = '.'
            gouv_col = 'gouvernorat'
        else:
            # Remplace NaN et chaînes vides par '.'
            df[gouv_col] = df[gouv_col].fillna('.').astype(str).replace(r'^\s*$', '.', regex=True)

        # Idem pour groupe d'âge
        if groupe_age_col is None:
            df['groupe_d_age'] = '.'
            groupe_age_col = 'groupe_d_age'
        else:
            df[groupe_age_col] = df[groupe_age_col].fillna('.').astype(str).replace(r'^\s*$', '.', regex=True)

        colonnes_instruction = [c for c in df.columns if c not in [gouv_col, 'total', groupe_age_col]]

        df_long = df.melt(
            id_vars=[gouv_col, groupe_age_col],
            value_vars=colonnes_instruction,
            var_name="niveaux_d_etude",
            value_name="valeur"
        )

        # Normaliser noms colonnes
        if gouv_col != 'gouvernorat':
            df_long = df_long.rename(columns={gouv_col: 'gouvernorat'})
            gouv_col = 'gouvernorat'
        if groupe_age_col != 'groupe_d_age':
            df_long = df_long.rename(columns={groupe_age_col: 'groupe_d_age'})
            groupe_age_col = 'groupe_d_age'

        df_long['sexe'] = sexe
        df_long['milieu'] = milieu
        df_long['annee'] = annee
        df_long['unite'] = unite
        df_long['feuille'] = feuille

        dfs_long.append(df_long)
        print(f"✅ Feuille '{feuille}' traitée.\n")

    except Exception as e:
        print(f"❌ Erreur dans la feuille '{feuille}': {e}\n")

if dfs_long:
    df_final = pd.concat(dfs_long, ignore_index=True)
    print("✅ Fusion terminée. Exemple :\n")
    print(df_final.head())
    df_final.to_excel("resultat_educ_auto.xlsx", index=False)
    print("📁 Données enregistrées dans 'resultat_educ_auto.xlsx'")

    with pd.option_context('display.max_rows', None, 'display.max_columns', None):
        print(df_final)
else:
    print("❌ Aucune donnée traitée.")
# Out:
# 📄 Traitement de la feuille : T72-55
# ✅ Feuille 'T72-55' traitée.
#
# 📄 Traitement de la feuille : T72-56
# ✅ Feuille 'T72-56' traitée.
#
# 📄 Traitement de la feuille : T72-57
# ✅ Feuille 'T72-57' traitée.
#
# 📄 Traitement de la feuille : T72-58
# ✅ Feuille 'T72-58' traitée.
#
# 📄 Traitement de la feuille : T72-59
# ✅ Feuille 'T72-59' traitée.
#
# 📄 Traitement de la feuille : T72-60
# ✅ Feuille 'T72-60' traitée.
#
# 📄 Traitement de la feuille : T72-61
# ✅ Feuille 'T72-61' traitée.
#
# 📄 Traitement de la feuille : T72-62
# ✅ Feuille 'T72-62' traitée.
#
# 📄 Traitement de la feuille : T72-63
# ✅ Feuille 'T72-63' traitée.
#
# 📄 Traitement de la feuille : T72-64
# ✅ Feuille 'T72-64' traitée.
#
# 📄 Traitement de la feuille : T72-65
# ✅ Feuille 'T72-65' traitée.
#
# 📄 Traitement de la feuille : T72-66
# ✅ Feuille 'T72-66' traitée.
#
# 📄 Traitement de la feuille : T72-67
# ✅ Feuille 'T72-67' traitée.
#
# 📄 Traitement de la feuille : T72-68
# ✅ Feuille 'T72-68' traitée.
#
# 📄 Traitement de la feuille : T72-69
# ✅ Feuille 'T72-69' traitée.
#
# 📄 Traitement de la feuille : T72-70
# ✅ Feuille 'T72-70' traitée.
#
# 📄 Traitement de la feuille : T72-71
# ✅ Feuille 'T72-71' traitée.
#
# 📄 Traitement de la feuille : T72-72
# ✅ Feuille 'T72-72' traitée.
#
# 📄 Traitement de la feuille : T72-73
# ✅ Feuille 'T72-73' traitée.
#
# 📄 Traitement de la feuille : T72-74
# ✅ Feuille 'T72-74' traitée.
#
# 📄 Traitement de la feuille : T72-75
# ✅ Feuille 'T72-75' traitée.
#
# 📄 Traitement de la feuille : T72-76
# ✅ Feuille 'T72-76' traitée.
#
# 📄 Traitement de la feuille : T72-77
# ✅ Feuille 'T72-77' traitée.
#
# 📄 Traitement de la feuille : T72-78
# ✅ Feuille 'T72-78' traitée.
#
# 📄 Traitement de la feuille : T72-79
# ✅ Feuille 'T72-79' traitée.
#
# 📄 Traitement de la feuille : T72-80
# ✅ Feuille 'T72-80' traitée.
#
# 📄 Traitement de la feuille : T72-81
# ✅ Feuille 'T72-81' traitée.
#
# 📄 Traitement de la feuille : T72-82
# ✅ Feuille 'T72-82' traitée.
#
# 📄 Traitement de la feuille : T72-83
# ✅ Feuille 'T72-83' traitée.
#
# 📄 Traitement de la feuille : T72-84
# ✅ Feuille 'T72-84' traitée.
#
# 📄 Traitement de la feuille : T72-85
# ✅ Feuille 'T72-85' traitée.
#
# 📄 Traitement de la feuille : T72-86
# ✅ Feuille 'T72-86' traitée.
#
# 📄 Traitement de la feuille : T72-87
# ✅ Feuille 'T72-87' traitée.
#
# 📄 Traitement de la feuille : T72-88
# ✅ Feuille 'T72-88' traitée.
#
# 📄 Traitement de la feuille : T72-89
# ✅ Feuille 'T72-89' traitée.
#
# ✅ Fusion terminée. Exemple :
#
#   gouvernorat groupe_d_age niveaux_d_etude valeur      sexe    milieu  annee  \
# 0           .       10--14    non_declares   6147  Ensemble  Ensemble   1994
# 1           .        15-19    non_declares   3021  Ensemble  Ensemble   1994
# 2           .        20-24    non_declares   2049  Ensemble  Ensemble   1994
# 3           .        25-29    non_declares   2062  Ensemble  Ensemble   1994
# 4           .        30-34    non_declares   1867  Ensemble  Ensemble   1994
#
#       unite feuille
# 0  effectif  T72-55
# 1  effectif  T72-55
# 2  effectif  T72-55
# 3  effectif  T72-55
# 4  effectif  T72-55
# 📁 Données enregistrées dans 'resultat_educ_auto.xlsx'
#         gouvernorat groupe_d_age niveaux_d_etude   valeur      sexe    milieu  \
# 0                 .       10--14    non_declares     6147  Ensemble  Ensemble
# 1                 .        15-19    non_declares     3021  Ensemble  Ensemble
# 2                 .        20-24    non_declares     2049  Ensemble  Ensemble
# 3                 .        25-29    non_declares     2062  Ensemble  Ensemble
# 4                 .        30-34    non_declares     1867  Ensemble  Ensemble
# 5                 .        35-39    non_declares     1747  Ensemble  Ensemble
# 6                 .        40-44    non_declares     1482  Ensemble  Ensemble
# 7                 .        45-49    non_declares      857  Ensemble  Ensemble
# 8                 .        50-54    non_declares      811  Ensemble  Ensemble
# 9                 .        55-59    non_declares      837  Ensemble  Ensemble
# 10                .        60-64    non_declares      714  Ensemble  Ensemble
# 11                .        65-69    non_declares      444  Ensemble  Ensemble
# 12                .        70-74    non_declares      479  Ensemble  Ensemble
# 13                .        75-79    non_declares      200  Ensemble  Ensemble
# 14                .    80 ans &+    non_declares      229  Ensemble  Ensemble
# 15                .        Total    non_declares    22946  Ensemble  Ensemble
# 16                .       10--14       superieur       73  Ensemble  Ensemble
# 17                .        15-19       superieur     2487  Ensemble  Ensemble
# 18                .        20-24       superieur    54287  Ensemble  Ensemble
# 19                .        25-29       superieur    63996  Ensemble  Ensemble
# 20                .        30-34       superieur    41096  Ensemble  Ensemble
# 21                .        35-39       superieur    34031  Ensemble  Ensemble
# 22                .        40-44       superieur    26408  Ensemble  Ensemble
# 23                .        45-49       superieur    15091  Ensemble  Ensemble
# 24                .        50-54       superieur     8371  Ensemble  Ensemble
# 25                .        55-59       superieur     4678  Ensemble  Ensemble
# 26                .        60-64       superieur     3018  Ensemble  Ensemble
# 27                .        65-69       superieur     1434  Ensemble  Ensemble
# 28                .        70-74       superieur      698  Ensemble  Ensemble
# 29                .        75-79       superieur      366  Ensemble  Ensemble
# 30                .    80 ans &+       superieur      348  Ensemble  Ensemble
# 31                .        Total       superieur   256382  Ensemble  Ensemble
# 32                .       10--14     second_prof      405  Ensemble  Ensemble
# 33                .        15-19     second_prof     5831  Ensemble  Ensemble
# 34                .        20-24     second_prof    29531  Ensemble  Ensemble
# 35                .        25-29     second_prof    30631  Ensemble  Ensemble
# 36                .        30-34     second_prof    24526  Ensemble  Ensemble
# 37                .        35-39     second_prof    11765  Ensemble  Ensemble
# 38                .        40-44     second_prof     6597  Ensemble  Ensemble
# 39                .        45-49     second_prof     3961  Ensemble  Ensemble
# 40                .        50-54     second_prof     1956  Ensemble  Ensemble
# 41                .        55-59     second_prof      923  Ensemble  Ensemble
# 42                .        60-64     second_prof      444  Ensemble  Ensemble
# 43                .        65-69     second_prof      183  Ensemble  Ensemble
# 44                .        70-74     second_prof       59  Ensemble  Ensemble
# 45                .        75-79     second_prof       61  Ensemble  Ensemble
# 46                .    80 ans &+     second_prof       51  Ensemble  Ensemble
# 47                .        Total     second_prof   116924  Ensemble  Ensemble
# 48                .       10--14     second_long   113916  Ensemble  Ensemble
# 49                .        15-19     second_long   442569  Ensemble  Ensemble
# 50                .        20-24     second_long   304912  Ensemble  Ensemble
# 51                .        25-29     second_long   197727  Ensemble  Ensemble
# 52                .        30-34     second_long   138243  Ensemble  Ensemble
# 53                .        35-39     second_long   119278  Ensemble  Ensemble
# 54                .        40-44     second_long    97749  Ensemble  Ensemble
# 55                .        45-49     second_long    46602  Ensemble  Ensemble
# 56                .        50-54     second_long    23209  Ensemble  Ensemble
# 57                .        55-59     second_long    15358  Ensemble  Ensemble
# 58                .        60-64     second_long     9193  Ensemble  Ensemble
# 59                .        65-69     second_long     5183  Ensemble  Ensemble
# 60                .        70-74     second_long     3328  Ensemble  Ensemble
# 61                .        75-79     second_long     1763  Ensemble  Ensemble
# 62                .    80 ans &+     second_long     1495  Ensemble  Ensemble
# 63                .        Total     second_long  1520525  Ensemble  Ensemble
# 64                .       10--14        primaire   848964  Ensemble  Ensemble
# 65                .        15-19        primaire   395903  Ensemble  Ensemble
# 66                .        20-24        primaire   302612  Ensemble  Ensemble
# 67                .        25-29        primaire   276124  Ensemble  Ensemble
# 68                .        30-34        primaire   287488  Ensemble  Ensemble
# 69                .        35-39        primaire   222468  Ensemble  Ensemble
# 70                .        40-44        primaire   122822  Ensemble  Ensemble
# 71                .        45-49        primaire    63986  Ensemble  Ensemble
# 72                .        50-54        primaire    35275  Ensemble  Ensemble
# 73                .        55-59        primaire    24532  Ensemble  Ensemble
# 74                .        60-64        primaire    17274  Ensemble  Ensemble
# 75                .        65-69        primaire    11195  Ensemble  Ensemble
# 76                .        70-74        primaire     6561  Ensemble  Ensemble
# 77                .        75-79        primaire     3170  Ensemble  Ensemble
# 78                .    80 ans &+        primaire     2414  Ensemble  Ensemble
# 79                .        Total        primaire  2620788  Ensemble  Ensemble
# 80                .       10--14         koutteb      888  Ensemble  Ensemble
# 81                .        15-19         koutteb      562  Ensemble  Ensemble
# 82                .        20-24         koutteb      757  Ensemble  Ensemble
# 83                .        25-29         koutteb     1125  Ensemble  Ensemble
# 84                .        30-34         koutteb     1476  Ensemble  Ensemble
# 85                .        35-39         koutteb     2643  Ensemble  Ensemble
# 86                .        40-44         koutteb     5401  Ensemble  Ensemble
# 87                .        45-49         koutteb     9654  Ensemble  Ensemble
# 88                .        50-54         koutteb    13117  Ensemble  Ensemble
# 89                .        55-59         koutteb    15295  Ensemble  Ensemble
# 90                .        60-64         koutteb    13944  Ensemble  Ensemble
# 91                .        65-69         koutteb    10036  Ensemble  Ensemble
# 92                .        70-74         koutteb     6291  Ensemble  Ensemble
# 93                .        75-79         koutteb     3961  Ensemble  Ensemble
# 94                .    80 ans &+         koutteb     3565  Ensemble  Ensemble
# 95                .        Total         koutteb    88715  Ensemble  Ensemble
# 96                .       10--14           neant    64253  Ensemble  Ensemble
# 97                .        15-19           neant    88693  Ensemble  Ensemble
# 98                .        20-24           neant   124570  Ensemble  Ensemble
# 99                .        25-29           neant   172238  Ensemble  Ensemble
# 100               .        30-34           neant   161919  Ensemble  Ensemble
# 101               .        35-39           neant   168415  Ensemble  Ensemble
# 102               .        40-44           neant   177434  Ensemble  Ensemble
# 103               .        45-49           neant   166998  Ensemble  Ensemble
# 104               .        50-54           neant   187618  Ensemble  Ensemble
# 105               .        55-59           neant   205117  Ensemble  Ensemble
# 106               .        60-64           neant   206776  Ensemble  Ensemble
# 107               .        65-69           neant   145380  Ensemble  Ensemble
# 108               .        70-74           neant   119761  Ensemble  Ensemble
# 109               .        75-79           neant    67681  Ensemble  Ensemble
# 110               .    80 ans &+           neant    78904  Ensemble  Ensemble
# 111               .        Total           neant  2135757  Ensemble  Ensemble
# 112               .       10--14    non_declares     3195  Masculin  Ensemble
# 113               .        15-19    non_declares     1189  Masculin  Ensemble
# 114               .        20-24    non_declares     1093  Masculin  Ensemble
# 115               .        25-29    non_declares     1163  Masculin  Ensemble
# 116               .        30-34    non_declares      886  Masculin  Ensemble
# 117               .        35-39    non_declares      828  Masculin  Ensemble
# 118               .        40-44    non_declares     1005  Masculin  Ensemble
# 119               .        45-49    non_declares      565  Masculin  Ensemble
# 120               .        50-54    non_declares      517  Masculin  Ensemble
# 121               .        55-59    non_declares      556  Masculin  Ensemble
# 122               .        60-64    non_declares      441  Masculin  Ensemble
# 123               .        65-69    non_declares      311  Masculin  Ensemble
# 124               .        70-74    non_declares      261  Masculin  Ensemble
# 125               .        75-79    non_declares      101  Masculin  Ensemble
# 126               .    80 ans &+    non_declares      125  Masculin  Ensemble
# 127               .        Total    non_declares    12236  Masculin  Ensemble
# 128               .       10--14       superieur       45  Masculin  Ensemble
# 129               .        15-19       superieur     1426  Masculin  Ensemble
# 130               .        20-24       superieur    30507  Masculin  Ensemble
# 131               .        25-29       superieur    40389  Masculin  Ensemble
# 132               .        30-34       superieur    27256  Masculin  Ensemble
# 133               .        35-39       superieur    24422  Masculin  Ensemble
# 134               .        40-44       superieur    20429  Masculin  Ensemble
# 135               .        45-49       superieur    11807  Masculin  Ensemble
# 136               .        50-54       superieur     6956  Masculin  Ensemble
# 137               .        55-59       superieur     4172  Masculin  Ensemble
# 138               .        60-64       superieur     2783  Masculin  Ensemble
# 139               .        65-69       superieur     1249  Masculin  Ensemble
# 140               .        70-74       superieur      639  Masculin  Ensemble
# 141               .        75-79       superieur      328  Masculin  Ensemble
# 142               .    80 ans &+       superieur      291  Masculin  Ensemble
# 143               .        Total       superieur   172699  Masculin  Ensemble
# 144               .       10--14     second_prof      211  Masculin  Ensemble
# 145               .        15-19     second_prof     3709  Masculin  Ensemble
# 146               .        20-24     second_prof    16037  Masculin  Ensemble
# 147               .        25-29     second_prof    18287  Masculin  Ensemble
# 148               .        30-34     second_prof    16870  Masculin  Ensemble
# 149               .        35-39     second_prof     8747  Masculin  Ensemble
# 150               .        40-44     second_prof     5139  Masculin  Ensemble
# 151               .        45-49     second_prof     2993  Masculin  Ensemble
# 152               .        50-54     second_prof     1443  Masculin  Ensemble
# 153               .        55-59     second_prof      707  Masculin  Ensemble
# 154               .        60-64     second_prof      369  Masculin  Ensemble
# 155               .        65-69     second_prof      139  Masculin  Ensemble
# 156               .        70-74     second_prof       51  Masculin  Ensemble
# 157               .        75-79     second_prof       47  Masculin  Ensemble
# 158               .    80 ans &+     second_prof       28  Masculin  Ensemble
# 159               .        Total     second_prof    74777  Masculin  Ensemble
# 160               .       10--14     second_long    57215  Masculin  Ensemble
# 161               .        15-19     second_long   243095  Masculin  Ensemble
# 162               .        20-24     second_long   178253  Masculin  Ensemble
# 163               .        25-29     second_long   118031  Masculin  Ensemble
# 164               .        30-34     second_long    84428  Masculin  Ensemble
# 165               .        35-39     second_long    77528  Masculin  Ensemble
# 166               .        40-44     second_long    67563  Masculin  Ensemble
# 167               .        45-49     second_long    32129  Masculin  Ensemble
# 168               .        50-54     second_long    17881  Masculin  Ensemble
# 169               .        55-59     second_long    12737  Masculin  Ensemble
# 170               .        60-64     second_long     8044  Masculin  Ensemble
# 171               .        65-69     second_long     4479  Masculin  Ensemble
# 172               .        70-74     second_long     2879  Masculin  Ensemble
# 173               .        75-79     second_long     1505  Masculin  Ensemble
# 174               .    80 ans &+     second_long     1188  Masculin  Ensemble
# 175               .        Total     second_long   906955  Masculin  Ensemble
# 176               .       10--14        primaire   451650  Masculin  Ensemble
# 177               .        15-19        primaire   208054  Masculin  Ensemble
# 178               .        20-24        primaire   159216  Masculin  Ensemble
# 179               .        25-29        primaire   144087  Masculin  Ensemble
# 180               .        30-34        primaire   153422  Masculin  Ensemble
# 181               .        35-39        primaire   126283  Masculin  Ensemble
# 182               .        40-44        primaire    72470  Masculin  Ensemble
# 183               .        45-49        primaire    39696  Masculin  Ensemble
# 184               .        50-54        primaire    26104  Masculin  Ensemble
# 185               .        55-59        primaire    19468  Masculin  Ensemble
# 186               .        60-64        primaire    14451  Masculin  Ensemble
# 187               .        65-69        primaire     9761  Masculin  Ensemble
# 188               .        70-74        primaire     5693  Masculin  Ensemble
# 189               .        75-79        primaire     2709  Masculin  Ensemble
# 190               .    80 ans &+        primaire     1914  Masculin  Ensemble
# 191               .        Total        primaire  1434978  Masculin  Ensemble
# 192               .       10--14         koutteb      437  Masculin  Ensemble
# 193               .        15-19         koutteb      298  Masculin  Ensemble
# 194               .        20-24         koutteb      403  Masculin  Ensemble
# 195               .        25-29         koutteb      711  Masculin  Ensemble
# 196               .        30-34         koutteb      974  Masculin  Ensemble
# 197               .        35-39         koutteb     1897  Masculin  Ensemble
# 198               .        40-44         koutteb     4333  Masculin  Ensemble
# 199               .        45-49         koutteb     8499  Masculin  Ensemble
# 200               .        50-54         koutteb    12164  Masculin  Ensemble
# 201               .        55-59         koutteb    14560  Masculin  Ensemble
# 202               .        60-64         koutteb    13525  Masculin  Ensemble
# 203               .        65-69         koutteb     9702  Masculin  Ensemble
# 204               .        70-74         koutteb     6087  Masculin  Ensemble
# 205               .        75-79         koutteb     3839  Masculin  Ensemble
# 206               .    80 ans &+         koutteb     3506  Masculin  Ensemble
# 207               .        Total         koutteb    80935  Masculin  Ensemble
# 208               .       10--14           neant    17425  Masculin  Ensemble
# 209               .        15-19           neant    20847  Masculin  Ensemble
# 210               .        20-24           neant    26954  Masculin  Ensemble
# 211               .        25-29           neant    40935  Masculin  Ensemble
# 212               .        30-34           neant    42336  Masculin  Ensemble
# 213               .        35-39           neant    42592  Masculin  Ensemble
# 214               .        40-44           neant    48850  Masculin  Ensemble
# 215               .        45-49           neant    54151  Masculin  Ensemble
# 216               .        50-54           neant    67940  Masculin  Ensemble
# 217               .        55-59           neant    80954  Masculin  Ensemble
# 218               .        60-64           neant    87666  Masculin  Ensemble
# 219               .        65-69           neant    65401  Masculin  Ensemble
# 220               .        70-74           neant    53951  Masculin  Ensemble
# 221               .        75-79           neant    34017  Masculin  Ensemble
# 222               .    80 ans &+           neant    36891  Masculin  Ensemble
# 223               .        Total           neant   720910  Masculin  Ensemble
# 224               .       10--14    non_declares     2952   Feminin  Ensemble
# 225               .        15-19    non_declares     1832   Feminin  Ensemble
# 226               .        20-24    non_declares      956   Feminin  Ensemble
# 227               .        25-29    non_declares      899   Feminin  Ensemble
# 228               .        30-34    non_declares      981   Feminin  Ensemble
# 229               .        35-39    non_declares      919   Feminin  Ensemble
# 230               .        40-44    non_declares      477   Feminin  Ensemble
# 231               .        45-49    non_declares      292   Feminin  Ensemble
# 232               .        50-54    non_declares      294   Feminin  Ensemble
# 233               .        55-59    non_declares      281   Feminin  Ensemble
# 234               .        60-64    non_declares      273   Feminin  Ensemble
# 235               .        65-69    non_declares      133   Feminin  Ensemble
# 236               .        70-74    non_declares      218   Feminin  Ensemble
# 237               .        75-79    non_declares       99   Feminin  Ensemble
# 238               .    80 ans &+    non_declares      104   Feminin  Ensemble
# 239               .        Total    non_declares    10710   Feminin  Ensemble
# 240               .       10--14       superieur       28   Feminin  Ensemble
# 241               .        15-19       superieur     1061   Feminin  Ensemble
# 242               .        20-24       superieur    23780   Feminin  Ensemble
# 243               .        25-29       superieur    23607   Feminin  Ensemble
# 244               .        30-34       superieur    13840   Feminin  Ensemble
# 245               .        35-39       superieur     9609   Feminin  Ensemble
# 246               .        40-44       superieur     5979   Feminin  Ensemble
# 247               .        45-49       superieur     3284   Feminin  Ensemble
# 248               .        50-54       superieur     1415   Feminin  Ensemble
# 249               .        55-59       superieur      506   Feminin  Ensemble
# 250               .        60-64       superieur      235   Feminin  Ensemble
# 251               .        65-69       superieur      185   Feminin  Ensemble
# 252               .        70-74       superieur       59   Feminin  Ensemble
# 253               .        75-79       superieur       38   Feminin  Ensemble
# 254               .    80 ans &+       superieur       57   Feminin  Ensemble
# 255               .        Total       superieur    83683   Feminin  Ensemble
# 256               .       10--14     second_prof      194   Feminin  Ensemble
# 257               .        15-19     second_prof     2122   Feminin  Ensemble
# 258               .        20-24     second_prof    13494   Feminin  Ensemble
# 259               .        25-29     second_prof    12344   Feminin  Ensemble
# 260               .        30-34     second_prof     7656   Feminin  Ensemble
# 261               .        35-39     second_prof     3018   Feminin  Ensemble
# 262               .        40-44     second_prof     1458   Feminin  Ensemble
# 263               .        45-49     second_prof      968   Feminin  Ensemble
# 264               .        50-54     second_prof      513   Feminin  Ensemble
# 265               .        55-59     second_prof      216   Feminin  Ensemble
# 266               .        60-64     second_prof       75   Feminin  Ensemble
# 267               .        65-69     second_prof       44   Feminin  Ensemble
# 268               .        70-74     second_prof        8   Feminin  Ensemble
# 269               .        75-79     second_prof       14   Feminin  Ensemble
# 270               .    80 ans &+     second_prof       23   Feminin  Ensemble
# 271               .        Total     second_prof    42147   Feminin  Ensemble
# 272               .       10--14     second_long    56701   Feminin  Ensemble
# 273               .        15-19     second_long   199474   Feminin  Ensemble
# 274               .        20-24     second_long   126659   Feminin  Ensemble
# 275               .        25-29     second_long    79696   Feminin  Ensemble
# 276               .        30-34     second_long    53815   Feminin  Ensemble
# 277               .        35-39     second_long    41750   Feminin  Ensemble
# 278               .        40-44     second_long    30186   Feminin  Ensemble
# 279               .        45-49     second_long    14473   Feminin  Ensemble
# 280               .        50-54     second_long     5328   Feminin  Ensemble
# 281               .        55-59     second_long     2621   Feminin  Ensemble
# 282               .        60-64     second_long     1149   Feminin  Ensemble
# 283               .        65-69     second_long      704   Feminin  Ensemble
# 284               .        70-74     second_long      449   Feminin  Ensemble
# 285               .        75-79     second_long      258   Feminin  Ensemble
# 286               .    80 ans &+     second_long      307   Feminin  Ensemble
# 287               .        Total     second_long   613570   Feminin  Ensemble
# 288               .       10--14        primaire   397314   Feminin  Ensemble
# 289               .        15-19        primaire   187849   Feminin  Ensemble
# 290               .        20-24        primaire   143396   Feminin  Ensemble
# 291               .        25-29        primaire   132037   Feminin  Ensemble
# 292               .        30-34        primaire   134066   Feminin  Ensemble
# 293               .        35-39        primaire    96185   Feminin  Ensemble
# 294               .        40-44        primaire    50352   Feminin  Ensemble
# 295               .        45-49        primaire    24290   Feminin  Ensemble
# 296               .        50-54        primaire     9171   Feminin  Ensemble
# 297               .        55-59        primaire     5064   Feminin  Ensemble
# 298               .        60-64        primaire     2823   Feminin  Ensemble
# 299               .        65-69        primaire     1434   Feminin  Ensemble
# 300               .        70-74        primaire      868   Feminin  Ensemble
# 301               .        75-79        primaire      461   Feminin  Ensemble
# 302               .    80 ans &+        primaire      500   Feminin  Ensemble
# 303               .        Total        primaire  1185810   Feminin  Ensemble
# 304               .       10--14         koutteb      451   Feminin  Ensemble
# 305               .        15-19         koutteb      264   Feminin  Ensemble
# 306               .        20-24         koutteb      354   Feminin  Ensemble
# 307               .        25-29         koutteb      414   Feminin  Ensemble
# 308               .        30-34         koutteb      502   Feminin  Ensemble
# 309               .        35-39         koutteb      746   Feminin  Ensemble
# 310               .        40-44         koutteb     1068   Feminin  Ensemble
# 311               .        45-49         koutteb     1155   Feminin  Ensemble
# 312               .        50-54         koutteb      953   Feminin  Ensemble
# 313               .        55-59         koutteb      735   Feminin  Ensemble
# 314               .        60-64         koutteb      419   Feminin  Ensemble
# 315               .        65-69         koutteb      334   Feminin  Ensemble
# 316               .        70-74         koutteb      204   Feminin  Ensemble
# 317               .        75-79         koutteb      122   Feminin  Ensemble
# 318               .    80 ans &+         koutteb       59   Feminin  Ensemble
# 319               .        Total         koutteb     7780   Feminin  Ensemble
# 320               .       10--14           neant    46828   Feminin  Ensemble
# 321               .        15-19           neant    67846   Feminin  Ensemble
# 322               .        20-24           neant    97616   Feminin  Ensemble
# 323               .        25-29           neant   131303   Feminin  Ensemble
# 324               .        30-34           neant   119583   Feminin  Ensemble
# 325               .        35-39           neant   125823   Feminin  Ensemble
# 326               .        40-44           neant   128584   Feminin  Ensemble
# 327               .        45-49           neant   112847   Feminin  Ensemble
# 328               .        50-54           neant   119678   Feminin  Ensemble
# 329               .        55-59           neant   124163   Feminin  Ensemble
# 330               .        60-64           neant   119110   Feminin  Ensemble
# 331               .        65-69           neant    79979   Feminin  Ensemble
# 332               .        70-74           neant    65810   Feminin  Ensemble
# 333               .        75-79           neant    33664   Feminin  Ensemble
# 334               .    80 ans &+           neant    42013   Feminin  Ensemble
# 335               .        Total           neant  1414847   Feminin  Ensemble
# 336               .       10--14    non_declares     3407  Ensemble         C
# 337               .        15-19    non_declares     2079  Ensemble         C
# 338               .        20-24    non_declares     1223  Ensemble         C
# 339               .        25-29    non_declares     1380  Ensemble         C
# 340               .        30-34    non_declares     1279  Ensemble         C
# 341               .        35-39    non_declares     1269  Ensemble         C
# 342               .        40-44    non_declares     1238  Ensemble         C
# 343               .        45-49    non_declares      665  Ensemble         C
# 344               .        50-54    non_declares      609  Ensemble         C
# 345               .        55-59    non_declares      561  Ensemble         C
# 346               .        60-64    non_declares      470  Ensemble         C
# 347               .        65-69    non_declares      336  Ensemble         C
# 348               .        70-74    non_declares      340  Ensemble         C
# 349               .        75-79    non_declares      132  Ensemble         C
# 350               .    80 ans &+    non_declares      152  Ensemble         C
# 351               .        Total    non_declares    15140  Ensemble         C
# 352               .       10--14       superieur       61  Ensemble         C
# 353               .        15-19       superieur     2164  Ensemble         C
# 354               .        20-24       superieur    46203  Ensemble         C
# 355               .        25-29       superieur    55693  Ensemble         C
# 356               .        30-34       superieur    38128  Ensemble         C
# 357               .        35-39       superieur    32082  Ensemble         C
# 358               .        40-44       superieur    25155  Ensemble         C
# 359               .        45-49       superieur    14560  Ensemble         C
# 360               .        50-54       superieur     8172  Ensemble         C
# 361               .        55-59       superieur     4565  Ensemble         C
# 362               .        60-64       superieur     2952  Ensemble         C
# 363               .        65-69       superieur     1405  Ensemble         C
# 364               .        70-74       superieur      673  Ensemble         C
# 365               .        75-79       superieur      354  Ensemble         C
# 366               .    80 ans &+       superieur      343  Ensemble         C
# 367               .        Total       superieur   232510  Ensemble         C
# 368               .       10--14     second_prof      304  Ensemble         C
# 369               .        15-19     second_prof     4298  Ensemble         C
# 370               .        20-24     second_prof    21378  Ensemble         C
# 371               .        25-29     second_prof    23957  Ensemble         C
# 372               .        30-34     second_prof    20562  Ensemble         C
# 373               .        35-39     second_prof    10119  Ensemble         C
# 374               .        40-44     second_prof     5721  Ensemble         C
# 375               .        45-49     second_prof     3657  Ensemble         C
# 376               .        50-54     second_prof     1844  Ensemble         C
# 377               .        55-59     second_prof      888  Ensemble         C
# 378               .        60-64     second_prof      402  Ensemble         C
# 379               .        65-69     second_prof      179  Ensemble         C
# 380               .        70-74     second_prof       56  Ensemble         C
# 381               .        75-79     second_prof       58  Ensemble         C
# 382               .    80 ans &+     second_prof       51  Ensemble         C
# 383               .        Total     second_prof    93474  Ensemble         C
# 384               .       10--14     second_long    88986  Ensemble         C
# 385               .        15-19     second_long   320637  Ensemble         C
# 386               .        20-24     second_long   227332  Ensemble         C
# 387               .        25-29     second_long   158908  Ensemble         C
# 388               .        30-34     second_long   120251  Ensemble         C
# 389               .        35-39     second_long   104111  Ensemble         C
# 390               .        40-44     second_long    86155  Ensemble         C
# 391               .        45-49     second_long    43645  Ensemble         C
# 392               .        50-54     second_long    21969  Ensemble         C
# 393               .        55-59     second_long    14446  Ensemble         C
# 394               .        60-64     second_long     8621  Ensemble         C
# 395               .        65-69     second_long     4837  Ensemble         C
# 396               .        70-74     second_long     3088  Ensemble         C
# 397               .        75-79     second_long     1650  Ensemble         C
# 398               .    80 ans &+     second_long     1354  Ensemble         C
# 399               .        Total     second_long  1205990  Ensemble         C
# 400               .       10--14        primaire   499893  Ensemble         C
# 401               .        15-19        primaire   200273  Ensemble         C
# 402               .        20-24        primaire   171156  Ensemble         C
# 403               .        25-29        primaire   183954  Ensemble         C
# 404               .        30-34        primaire   202536  Ensemble         C
# 405               .        35-39        primaire   156748  Ensemble         C
# 406               .        40-44        primaire    91222  Ensemble         C
# 407               .        45-49        primaire    53589  Ensemble         C
# 408               .        50-54        primaire    30575  Ensemble         C
# 409               .        55-59        primaire    21750  Ensemble         C
# 410               .        60-64        primaire    15741  Ensemble         C
# 411               .        65-69        primaire    10246  Ensemble         C
# 412               .        70-74        primaire     6013  Ensemble         C
# 413               .        75-79        primaire     2903  Ensemble         C
# 414               .    80 ans &+        primaire     2089  Ensemble         C
# 415               .        Total        primaire  1648688  Ensemble         C
# 416               .       10--14         koutteb      544  Ensemble         C
# 417               .        15-19         koutteb      218  Ensemble         C
# 418               .        20-24         koutteb      425  Ensemble         C
# 419               .        25-29         koutteb      594  Ensemble         C
# 420               .        30-34         koutteb      816  Ensemble         C
# 421               .        35-39         koutteb     1378  Ensemble         C
# 422               .        40-44         koutteb     2721  Ensemble         C
# 423               .        45-49         koutteb     4745  Ensemble         C
# 424               .        50-54         koutteb     6717  Ensemble         C
# 425               .        55-59         koutteb     8630  Ensemble         C
# 426               .        60-64         koutteb     8382  Ensemble         C
# 427               .        65-69         koutteb     6117  Ensemble         C
# 428               .        70-74         koutteb     3717  Ensemble         C
# 429               .        75-79         koutteb     2310  Ensemble         C
# 430               .    80 ans &+         koutteb     2161  Ensemble         C
# 431               .        Total         koutteb    49475  Ensemble         C
# 432               .       10--14           neant    12265  Ensemble         C
# 433               .        15-19           neant    16621  Ensemble         C
# 434               .        20-24           neant    30202  Ensemble         C
# 435               .        25-29           neant    54625  Ensemble         C
# 436               .        30-34           neant    60118  Ensemble         C
# 437               .        35-39           neant    70546  Ensemble         C
# 438               .        40-44           neant    79008  Ensemble         C
# 439               .        45-49           neant    82750  Ensemble         C
# 440               .        50-54           neant    99711  Ensemble         C
# 441               .        55-59           neant   110693  Ensemble         C
# 442               .        60-64           neant   113747  Ensemble         C
# 443               .        65-69           neant    79557  Ensemble         C
# 444               .        70-74           neant    66075  Ensemble         C
# 445               .        75-79           neant    36637  Ensemble         C
# 446               .    80 ans &+           neant    43627  Ensemble         C
# 447               .        Total           neant   956182  Ensemble         C
# 448               .       10--14    non_declares     1893  Masculin         C
# 449               .        15-19    non_declares      811  Masculin         C
# 450               .        20-24    non_declares      688  Masculin         C
# 451               .        25-29    non_declares      820  Masculin         C
# 452               .        30-34    non_declares      617  Masculin         C
# 453               .        35-39    non_declares      541  Masculin         C
# 454               .        40-44    non_declares      846  Masculin         C
# 455               .        45-49    non_declares      460  Masculin         C
# 456               .        50-54    non_declares      421  Masculin         C
# 457               .        55-59    non_declares      409  Masculin         C
# 458               .        60-64    non_declares      290  Masculin         C
# 459               .        65-69    non_declares      240  Masculin         C
# 460               .        70-74    non_declares      190  Masculin         C
# 461               .        75-79    non_declares       63  Masculin         C
# 462               .    80 ans &+    non_declares       91  Masculin         C
# 463               .        Total    non_declares     8380  Masculin         C
# 464               .       10--14       superieur       37  Masculin         C
# 465               .        15-19       superieur     1171  Masculin         C
# 466               .        20-24       superieur    24840  Masculin         C
# 467               .        25-29       superieur    33732  Masculin         C
# 468               .        30-34       superieur    24730  Masculin         C
# 469               .        35-39       superieur    22669  Masculin         C
# 470               .        40-44       superieur    19283  Masculin         C
# 471               .        45-49       superieur    11323  Masculin         C
# 472               .        50-54       superieur     6784  Masculin         C
# 473               .        55-59       superieur     4067  Masculin         C
# 474               .        60-64       superieur     2717  Masculin         C
# 475               .        65-69       superieur     1220  Masculin         C
# 476               .        70-74       superieur      614  Masculin         C
# 477               .        75-79       superieur      322  Masculin         C
# 478               .    80 ans &+       superieur      286  Masculin         C
# 479               .        Total       superieur   153795  Masculin         C
# 480               .       10--14     second_prof      148  Masculin         C
# 481               .        15-19     second_prof     2588  Masculin         C
# 482               .        20-24     second_prof    10459  Masculin         C
# 483               .        25-29     second_prof    13050  Masculin         C
# 484               .        30-34     second_prof    13490  Masculin         C
# 485               .        35-39     second_prof     7273  Masculin         C
# 486               .        40-44     second_prof     4335  Masculin         C
# 487               .        45-49     second_prof     2728  Masculin         C
# 488               .        50-54     second_prof     1338  Masculin         C
# 489               .        55-59     second_prof      678  Masculin         C
# 490               .        60-64     second_prof      337  Masculin         C
# 491               .        65-69     second_prof      136  Masculin         C
# 492               .        70-74     second_prof       51  Masculin         C
# 493               .        75-79     second_prof       44  Masculin         C
# 494               .    80 ans &+     second_prof       28  Masculin         C
# 495               .        Total     second_prof    56683  Masculin         C
# 496               .       10--14     second_long    42780  Masculin         C
# 497               .        15-19     second_long   165148  Masculin         C
# 498               .        20-24     second_long   123572  Masculin         C
# 499               .        25-29     second_long    88324  Masculin         C
# 500               .        30-34     second_long    69897  Masculin         C
# 501               .        35-39     second_long    64810  Masculin         C
# 502               .        40-44     second_long    57193  Masculin         C
# 503               .        45-49     second_long    29371  Masculin         C
# 504               .        50-54     second_long    16741  Masculin         C
# 505               .        55-59     second_long    11877  Masculin         C
# 506               .        60-64     second_long     7501  Masculin         C
# 507               .        65-69     second_long     4179  Masculin         C
# 508               .        70-74     second_long     2645  Masculin         C
# 509               .        75-79     second_long     1399  Masculin         C
# 510               .    80 ans &+     second_long     1056  Masculin         C
# 511               .        Total     second_long   686493  Masculin         C
# 512               .       10--14        primaire   257595  Masculin         C
# 513               .        15-19        primaire   105353  Masculin         C
# 514               .        20-24        primaire    87287  Masculin         C
# 515               .        25-29        primaire    88495  Masculin         C
# 516               .        30-34        primaire    98836  Masculin         C
# 517               .        35-39        primaire    80409  Masculin         C
# 518               .        40-44        primaire    48088  Masculin         C
# 519               .        45-49        primaire    30929  Masculin         C
# 520               .        50-54        primaire    21847  Masculin         C
# 521               .        55-59        primaire    16923  Masculin         C
# 522               .        60-64        primaire    13068  Masculin         C
# 523               .        65-69        primaire     8931  Masculin         C
# 524               .        70-74        primaire     5180  Masculin         C
# 525               .        75-79        primaire     2475  Masculin         C
# 526               .    80 ans &+        primaire     1663  Masculin         C
# 527               .        Total        primaire   867079  Masculin         C
# 528               .       10--14         koutteb      285  Masculin         C
# 529               .        15-19         koutteb      119  Masculin         C
# 530               .        20-24         koutteb      213  Masculin         C
# 531               .        25-29         koutteb      322  Masculin         C
# 532               .        30-34         koutteb      466  Masculin         C
# 533               .        35-39         koutteb      861  Masculin         C
# 534               .        40-44         koutteb     1926  Masculin         C
# 535               .        45-49         koutteb     3868  Masculin         C
# 536               .        50-54         koutteb     5952  Masculin         C
# 537               .        55-59         koutteb     7996  Masculin         C
# 538               .        60-64         koutteb     8010  Masculin         C
# 539               .        65-69         koutteb     5835  Masculin         C
# 540               .        70-74         koutteb     3562  Masculin         C
# 541               .        75-79         koutteb     2200  Masculin         C
# 542               .    80 ans &+         koutteb     2116  Masculin         C
# 543               .        Total         koutteb    43731  Masculin         C
# 544               .       10--14           neant     4887  Masculin         C
# 545               .        15-19           neant     4827  Masculin         C
# 546               .        20-24           neant     7350  Masculin         C
# 547               .        25-29           neant    12377  Masculin         C
# 548               .        30-34           neant    14968  Masculin         C
# 549               .        35-39           neant    15650  Masculin         C
# 550               .        40-44           neant    18908  Masculin         C
# 551               .        45-49           neant    22711  Masculin         C
# 552               .        50-54           neant    31157  Masculin         C
# 553               .        55-59           neant    38988  Masculin         C
# ...
# 4924   1994         %  T72-87
# 4925   1994         %  T72-87
# 4926   1994         %  T72-87
# 4927   1994         %  T72-87
# 4928   1994         %  T72-87
# 4929   1994         %  T72-87
# 4930   1994         %  T72-87
# 4931   1994         %  T72-87
# 4932   1994         %  T72-87
# 4933   1994         %  T72-87
# 4934   1994         %  T72-87
# 4935   1994         %  T72-87
# 4936   1994         %  T72-87
# 4937   1994         %  T72-87
# 4938   1994         %  T72-87
# 4939   1994         %  T72-87
# 4940   1994         %  T72-87
# 4941   1994         %  T72-87
# 4942   1994         %  T72-87
# 4943   1994         %  T72-87
# 4944   1994         %  T72-87
# 4945   1994         %  T72-87
# 4946   1994         %  T72-87
# 4947   1994         %  T72-87
# 4948   1994         %  T72-87
# 4949   1994         %  T72-87
# 4950   1994         %  T72-87
# 4951   1994         %  T72-87
# 4952   1994         %  T72-87
# 4953   1994         %  T72-87
# 4954   1994         %  T72-87
# 4955   1994         %  T72-87
# 4956   1994         %  T72-87
# 4957   1994         %  T72-87
# 4958   1994         %  T72-87
# 4959   1994         %  T72-87
# 4960   1994         %  T72-87
# 4961   1994         %  T72-87
# 4962   1994         %  T72-87
# 4963   1994         %  T72-87
# 4964   1994         %  T72-87
# 4965   1994         %  T72-87
# 4966   1994         %  T72-87
# 4967   1994         %  T72-87
# 4968   1994         %  T72-87
# 4969   1994         %  T72-87
# 4970   1994         %  T72-87
# 4971   1994         %  T72-87
# 4972   1994         %  T72-87
# 4973   1994         %  T72-87
# 4974   1994         %  T72-87
# 4975   1994         %  T72-87
# 4976   1994         %  T72-87
# 4977   1994         %  T72-87
# 4978   1994         %  T72-87
# 4979   1994         %  T72-87
# 4980   1994         %  T72-87
# 4981   1994         %  T72-87
# 4982   1994         %  T72-87
# 4983   1994         %  T72-87
# 4984   1994         %  T72-87
# 4985   1994         %  T72-87
# 4986   1994         %  T72-87
# 4987   1994         %  T72-87
# 4988   1994         %  T72-87
# 4989   1994         %  T72-87
# 4990   1994         %  T72-87
# 4991   1994         %  T72-87
# 4992   1994         %  T72-87
# 4993   1994         %  T72-87
# 4994   1994         %  T72-87
# 4995   1994         %  T72-87
# 4996   1994         %  T72-87
# 4997   1994         %  T72-87
# 4998   1994         %  T72-87
# 4999   1994         %  T72-87
# 5000   1994         %  T72-87
# 5001   1994         %  T72-87
# 5002   1994         %  T72-87
# 5003   1994         %  T72-87
# 5004   1994         %  T72-87
# 5005   1994         %  T72-87
# 5006   1994         %  T72-87
# 5007   1994         %  T72-87
# 5008   1994         %  T72-87
# 5009   1994         %  T72-87
# 5010   1994         %  T72-87
# 5011   1994         %  T72-87
# 5012   1994         %  T72-87
# 5013   1994         %  T72-87
# 5014   1994         %  T72-87
# 5015   1994         %  T72-87
# 5016   1994         %  T72-87
# 5017   1994         %  T72-87
# 5018   1994         %  T72-87
# 5019   1994         %  T72-87
# 5020   1994         %  T72-87
# 5021   1994         %  T72-87
# 5022   1994         %  T72-87
# 5023   1994         %  T72-87
# 5024   1994         %  T72-87
# 5025   1994         %  T72-87
# 5026   1994         %  T72-87
# 5027   1994         %  T72-87
# 5028   1994         %  T72-87
# 5029   1994         %  T72-87
# 5030   1994         %  T72-87
# 5031   1994         %  T72-87
# 5032   1994         %  T72-87
# 5033   1994         %  T72-87
# 5034   1994         %  T72-87
# 5035   1994         %  T72-87
# 5036   1994         %  T72-87
# 5037   1994         %  T72-87
# 5038   1994         %  T72-87
# 5039   1994         %  T72-87
# 5040   1994         %  T72-88
# 5041   1994         %  T72-88
# 5042   1994         %  T72-88
# 5043   1994         %  T72-88
# 5044   1994         %  T72-88
# 5045   1994         %  T72-88
# 5046   1994         %  T72-88
# 5047   1994         %  T72-88
# 5048   1994         %  T72-88
# 5049   1994         %  T72-88
# 5050   1994         %  T72-88
# 5051   1994         %  T72-88
# 5052   1994         %  T72-88
# 5053   1994         %  T72-88
# 5054   1994         %  T72-88
# 5055   1994         %  T72-88
# 5056   1994         %  T72-88
# 5057   1994         %  T72-88
# 5058   1994         %  T72-88
# 5059   1994         %  T72-88
# 5060   1994         %  T72-88
# 5061   1994         %  T72-88
# 5062   1994         %  T72-88
# 5063   1994         %  T72-88
# 5064   1994         %  T72-88
# 5065   1994         %  T72-88
# 5066   1994         %  T72-88
# 5067   1994         %  T72-88
# 5068   1994         %  T72-88
# 5069   1994         %  T72-88
# 5070   1994         %  T72-88
# 5071   1994         %  T72-88
# 5072   1994         %  T72-88
# 5073   1994         %  T72-88
# 5074   1994         %  T72-88
# 5075   1994         %  T72-88
# 5076   1994         %  T72-88
# 5077   1994         %  T72-88
# 5078   1994         %  T72-88
# 5079   1994         %  T72-88
# 5080   1994         %  T72-88
# 5081   1994         %  T72-88
# 5082   1994         %  T72-88
# 5083   1994         %  T72-88
# 5084   1994         %  T72-88
# 5085   1994         %  T72-88
# 5086   1994         %  T72-88
# 5087   1994         %  T72-88
# 5088   1994         %  T72-88
# 5089   1994         %  T72-88
# 5090   1994         %  T72-88
# 5091   1994         %  T72-88
# 5092   1994         %  T72-88
# 5093   1994         %  T72-88
# 5094   1994         %  T72-88
# 5095   1994         %  T72-88
# 5096   1994         %  T72-88
# 5097   1994         %  T72-88
# 5098   1994         %  T72-88
# 5099   1994         %  T72-88
# 5100   1994         %  T72-88
# 5101   1994         %  T72-88
# 5102   1994         %  T72-88
# 5103   1994         %  T72-88
# 5104   1994         %  T72-88
# 5105   1994         %  T72-88
# 5106   1994         %  T72-88
# 5107   1994         %  T72-88
# 5108   1994         %  T72-88
# 5109   1994         %  T72-88
# 5110   1994         %  T72-88
# 5111   1994         %  T72-88
# 5112   1994         %  T72-88
# 5113   1994         %  T72-88
# 5114   1994         %  T72-88
# 5115   1994         %  T72-88
# 5116   1994         %  T72-88
# 5117   1994         %  T72-88
# 5118   1994         %  T72-88
# 5119   1994         %  T72-88
# 5120   1994         %  T72-88
# 5121   1994         %  T72-88
# 5122   1994         %  T72-88
# 5123   1994         %  T72-88
# 5124   1994         %  T72-88
# 5125   1994         %  T72-88
# 5126   1994         %  T72-88
# 5127   1994         %  T72-88
# 5128   1994         %  T72-88
# 5129   1994         %  T72-88
# 5130   1994         %  T72-88
# 5131   1994         %  T72-88
# 5132   1994         %  T72-88
# 5133   1994         %  T72-88
# 5134   1994         %  T72-88
# 5135   1994         %  T72-88
# 5136   1994         %  T72-88
# 5137   1994         %  T72-88
# 5138   1994         %  T72-88
# 5139   1994         %  T72-88
# 5140   1994         %  T72-88
# 5141   1994         %  T72-88
# 5142   1994         %  T72-88
# 5143   1994         %  T72-88
# 5144   1994         %  T72-88
# 5145   1994         %  T72-88
# 5146   1994         %  T72-88
# 5147   1994         %  T72-88
# 5148   1994         %  T72-88
# 5149   1994         %  T72-88
# 5150   1994         %  T72-88
# 5151   1994         %  T72-88
# 5152   1994         %  T72-88
# 5153   1994         %  T72-88
# 5154   1994         %  T72-88
# 5155   1994         %  T72-88
# 5156   1994         %  T72-88
# 5157   1994         %  T72-88
# 5158   1994         %  T72-88
# 5159   1994         %  T72-88
# 5160   1994         %  T72-88
# 5161   1994         %  T72-88
# 5162   1994         %  T72-88
# 5163   1994         %  T72-88
# 5164   1994         %  T72-88
# 5165   1994         %  T72-88
# 5166   1994         %  T72-88
# 5167   1994         %  T72-88
# 5168   1994         %  T72-88
# 5169   1994         %  T72-88
# 5170   1994         %  T72-88
# 5171   1994         %  T72-88
# 5172   1994         %  T72-88
# 5173   1994         %  T72-88
# 5174   1994         %  T72-88
# 5175   1994         %  T72-88
# 5176   1994         %  T72-88
# 5177   1994         %  T72-88
# 5178   1994         %  T72-88
# 5179   1994         %  T72-88
# 5180   1994         %  T72-88
# 5181   1994         %  T72-88
# 5182   1994         %  T72-88
# 5183   1994         %  T72-88
# 5184   1994         %  T72-88
# 5185   1994         %  T72-88
# 5186   1994         %  T72-88
# 5187   1994         %  T72-88
# 5188   1994         %  T72-88
# 5189   1994         %  T72-88
# 5190   1994         %  T72-88
# 5191   1994         %  T72-88
# 5192   1994         %  T72-88
# 5193   1994         %  T72-88
# 5194   1994         %  T72-88
# 5195   1994         %  T72-88
# 5196   1994         %  T72-88
# 5197   1994         %  T72-88
# 5198   1994         %  T72-88
# 5199   1994         %  T72-88
# 5200   1994         %  T72-88
# 5201   1994         %  T72-88
# 5202   1994         %  T72-88
# 5203   1994         %  T72-88
# 5204   1994         %  T72-88
# 5205   1994         %  T72-88
# 5206   1994         %  T72-88
# 5207   1994         %  T72-88
# 5208   1994         %  T72-88
# 5209   1994         %  T72-88
# 5210   1994         %  T72-88
# 5211   1994         %  T72-88
# 5212   1994         %  T72-88
# 5213   1994         %  T72-88
# 5214   1994         %  T72-88
# 5215   1994         %  T72-88
# 5216   1994         %  T72-88
# 5217   1994         %  T72-88
# 5218   1994         %  T72-88
# 5219   1994         %  T72-88
# 5220   1994         %  T72-88
# 5221   1994         %  T72-88
# 5222   1994         %  T72-88
# 5223   1994         %  T72-88
# 5224   1994         %  T72-88
# 5225   1994         %  T72-88
# 5226   1994         %  T72-88
# 5227   1994         %  T72-88
# 5228   1994         %  T72-88
# 5229   1994         %  T72-88
# 5230   1994         %  T72-88
# 5231   1994         %  T72-88
# 5232   1994         %  T72-89
# 5233   1994         %  T72-89
# 5234   1994         %  T72-89
# 5235   1994         %  T72-89
# 5236   1994         %  T72-89
# 5237   1994         %  T72-89
# 5238   1994         %  T72-89
# 5239   1994         %  T72-89
# 5240   1994         %  T72-89
# 5241   1994         %  T72-89
# 5242   1994         %  T72-89
# 5243   1994         %  T72-89
# 5244   1994         %  T72-89
# 5245   1994         %  T72-89
# 5246   1994         %  T72-89
# 5247   1994         %  T72-89
# 5248   1994         %  T72-89
# 5249   1994         %  T72-89
# 5250   1994         %  T72-89
# 5251   1994         %  T72-89
# 5252   1994         %  T72-89
# 5253   1994         %  T72-89
# 5254   1994         %  T72-89
# 5255   1994         %  T72-89
# 5256   1994         %  T72-89
# 5257   1994         %  T72-89
# 5258   1994         %  T72-89
# 5259   1994         %  T72-89
# 5260   1994         %  T72-89
# 5261   1994         %  T72-89
# 5262   1994         %  T72-89
# 5263   1994         %  T72-89
# 5264   1994         %  T72-89
# 5265   1994         %  T72-89
# 5266   1994         %  T72-89
# 5267   1994         %  T72-89
# 5268   1994         %  T72-89
# 5269   1994         %  T72-89
# 5270   1994         %  T72-89
# 5271   1994         %  T72-89
# 5272   1994         %  T72-89
# 5273   1994         %  T72-89
# 5274   1994         %  T72-89
# 5275   1994         %  T72-89
# 5276   1994         %  T72-89
# 5277   1994         %  T72-89
# 5278   1994         %  T72-89
# 5279   1994         %  T72-89
# 5280   1994         %  T72-89
# 5281   1994         %  T72-89
# 5282   1994         %  T72-89
# 5283   1994         %  T72-89
# 5284   1994         %  T72-89
# 5285   1994         %  T72-89
# 5286   1994         %  T72-89
# 5287   1994         %  T72-89
# 5288   1994         %  T72-89
# 5289   1994         %  T72-89
# 5290   1994         %  T72-89
# 5291   1994         %  T72-89
# 5292   1994         %  T72-89
# 5293   1994         %  T72-89
# 5294   1994         %  T72-89
# 5295   1994         %  T72-89
# 5296   1994         %  T72-89
# 5297   1994         %  T72-89
# 5298   1994         %  T72-89
# 5299   1994         %  T72-89
# 5300   1994         %  T72-89
# 5301   1994         %  T72-89
# 5302   1994         %  T72-89
# 5303   1994         %  T72-89
# 5304   1994         %  T72-89
# 5305   1994         %  T72-89
# 5306   1994         %  T72-89
# 5307   1994         %  T72-89
# 5308   1994         %  T72-89
# 5309   1994         %  T72-89
# 5310   1994         %  T72-89
# 5311   1994         %  T72-89
# 5312   1994         %  T72-89
# 5313   1994         %  T72-89
# 5314   1994         %  T72-89
# 5315   1994         %  T72-89
# 5316   1994         %  T72-89
# 5317   1994         %  T72-89
# 5318   1994         %  T72-89
# 5319   1994         %  T72-89
# 5320   1994         %  T72-89
# 5321   1994         %  T72-89
# 5322   1994         %  T72-89
# 5323   1994         %  T72-89
# 5324   1994         %  T72-89
# 5325   1994         %  T72-89
# 5326   1994         %  T72-89
# 5327   1994         %  T72-89
# 5328   1994         %  T72-89
# 5329   1994         %  T72-89
# 5330   1994         %  T72-89
# 5331   1994         %  T72-89
# 5332   1994         %  T72-89
# 5333   1994         %  T72-89
# 5334   1994         %  T72-89
# 5335   1994         %  T72-89
# 5336   1994         %  T72-89
# 5337   1994         %  T72-89
# 5338   1994         %  T72-89
# 5339   1994         %  T72-89
# 5340   1994         %  T72-89
# 5341   1994         %  T72-89
# 5342   1994         %  T72-89
# 5343   1994         %  T72-89
# 5344   1994         %  T72-89
# 5345   1994         %  T72-89
# 5346   1994         %  T72-89
# 5347   1994         %  T72-89
# 5348   1994         %  T72-89
# 5349   1994         %  T72-89
# 5350   1994         %  T72-89
# 5351   1994         %  T72-89
# 5352   1994         %  T72-89
# 5353   1994         %  T72-89
# 5354   1994         %  T72-89
# 5355   1994         %  T72-89
# 5356   1994         %  T72-89
# 5357   1994         %  T72-89
# 5358   1994         %  T72-89
# 5359   1994         %  T72-89
# 5360   1994         %  T72-89
# 5361   1994         %  T72-89
# 5362   1994         %  T72-89
# 5363   1994         %  T72-89
# 5364   1994         %  T72-89
# 5365   1994         %  T72-89
# 5366   1994         %  T72-89
# 5367   1994         %  T72-89
# 5368   1994         %  T72-89
# 5369   1994         %  T72-89
# 5370   1994         %  T72-89
# 5371   1994         %  T72-89
# 5372   1994         %  T72-89
# 5373   1994         %  T72-89
# 5374   1994         %  T72-89
# 5375   1994         %  T72-89
# 5376   1994         %  T72-89
# 5377   1994         %  T72-89
# 5378   1994         %  T72-89
# 5379   1994         %  T72-89
# 5380   1994         %  T72-89
# 5381   1994         %  T72-89
# 5382   1994         %  T72-89
# 5383   1994         %  T72-89
# 5384   1994         %  T72-89
# 5385   1994         %  T72-89
# 5386   1994         %  T72-89
# 5387   1994         %  T72-89
# 5388   1994         %  T72-89
# 5389   1994         %  T72-89
# 5390   1994         %  T72-89
# 5391   1994         %  T72-89
# 5392   1994         %  T72-89
# 5393   1994         %  T72-89
# 5394   1994         %  T72-89
# 5395   1994         %  T72-89
# 5396   1994         %  T72-89
# 5397   1994         %  T72-89
# 5398   1994         %  T72-89
# 5399   1994         %  T72-89
# 5400   1994         %  T72-89
# 5401   1994         %  T72-89
# 5402   1994         %  T72-89
# 5403   1994         %  T72-89
# 5404   1994         %  T72-89
# 5405   1994         %  T72-89
# 5406   1994         %  T72-89
# 5407   1994         %  T72-89
# 5408   1994         %  T72-89
# 5409   1994         %  T72-89
# 5410   1994         %  T72-89
# 5411   1994         %  T72-89
# 5412   1994         %  T72-89
# 5413   1994         %  T72-89
# 5414   1994         %  T72-89
# 5415   1994         %  T72-89
# 5416   1994         %  T72-89
# 5417   1994         %  T72-89
# 5418   1994         %  T72-89
# 5419   1994         %  T72-89
# 5420   1994         %  T72-89
# 5421   1994         %  T72-89
# 5422   1994         %  T72-89
# 5423   1994         %  T72-89

# %% [markdown]
# # code version finale

# %%
import pandas as pd
import re
import unicodedata

def enlever_accents(text):
    return ''.join(
        c for c in unicodedata.normalize('NFD', str(text))
        if unicodedata.category(c) != 'Mn'
    )

def nettoyer_texte(text):
    return enlever_accents(text.lower())

def nettoyer_colonnes(cols):
    return [nettoyer_texte(c).replace(' ', '_') for c in cols]

def detecter_sexe(titre_str):
    t = nettoyer_texte(titre_str)
    if 'masculin' in t:
        return 'Masculin'
    elif 'feminin' in t:
        return 'Feminin'
    elif 'ensemble sexes' in t or 'ensemble sexe' in t:
        return 'Ensemble'
    return '.'

def detecter_milieu(titre_str):
    t = nettoyer_texte(titre_str)
    if 'non communal' in t:
        return 'NC'
    elif 'communal' in t:
        return 'C'
    elif 'ensemble milieux' in t or 'ensemble milieu' in t:
        return 'Ensemble'
    return '.'

def detecter_unite(titre_str):
    t = nettoyer_texte(titre_str)
    if '%' in titre_str or 'pourcentage' in t:
        return '%'
    elif 'nombre' in t or 'effectif' in t:
        return 'effectif'
    return 'effectif'

def trouver_colonne_similaire(df, mots_cles):
    for col in df.columns:
        col_nettoyee = nettoyer_texte(col)
        if all(mot in col_nettoyee for mot in mots_cles):
            return col
    return None

fichier_excel = 'educ.xlsx'
xls = pd.ExcelFile(fichier_excel)

pattern = re.compile(r'^T72-(\d{2})$')
feuilles = [f for f in xls.sheet_names if pattern.match(f) and 55 <= int(pattern.match(f).group(1)) <= 89]

dfs_long = []

for feuille in feuilles:
    try:
        print(f"📄 Traitement de la feuille : {feuille}")
        titres = pd.read_excel(xls, sheet_name=feuille, nrows=2, header=None)
        titre_str = ' '.join(titres.astype(str).fillna('').values.flatten())

        sexe = detecter_sexe(titre_str)
        milieu = detecter_milieu(titre_str)
        unite = detecter_unite(titre_str)

        annee_match = re.search(r'\b(19\d{2}|20\d{2})\b', titre_str)
        if annee_match:
            annee = int(annee_match.group(1))
        else:
            match = pattern.match(feuille)
            annee = int("19" + match.group(1)) if match else '.'

        df = pd.read_excel(xls, sheet_name=feuille, skiprows=2)
        df.columns = nettoyer_colonnes(df.columns)

        # Recherche colonnes gouvernorat et groupe d'âge
        gouv_col = trouver_colonne_similaire(df, ['gouver'])
        groupe_age_col = trouver_colonne_similaire(df, ['groupe', 'age'])

        # Si la colonne gouvernorat n'existe pas, on la crée avec '.'
        if gouv_col is None:
            df['gouvernorat'] = '.'
            gouv_col = 'gouvernorat'
        else:
            # Remplace NaN et chaînes vides par '.'
            df[gouv_col] = df[gouv_col].fillna('.').astype(str).replace(r'^\s*$', '.', regex=True)

        # Idem pour groupe d'âge
        if groupe_age_col is None:
            df['groupe_d_age'] = '.'
            groupe_age_col = 'groupe_d_age'
        else:
            df[groupe_age_col] = df[groupe_age_col].fillna('.').astype(str).replace(r'^\s*$', '.', regex=True)

        colonnes_instruction = [c for c in df.columns if c not in [gouv_col, 'total', groupe_age_col]]

        df_long = df.melt(
            id_vars=[gouv_col, groupe_age_col],
            value_vars=colonnes_instruction,
            var_name="niveaux_d_etude",
            value_name="valeur"
        )

        # Normaliser noms colonnes
        if gouv_col != 'gouvernorat':
            df_long = df_long.rename(columns={gouv_col: 'gouvernorat'})
            gouv_col = 'gouvernorat'
        if groupe_age_col != 'groupe_d_age':
            df_long = df_long.rename(columns={groupe_age_col: 'groupe_d_age'})
            groupe_age_col = 'groupe_d_age'
        df_long.insert(0, 'indicateur', 'Population âgée de 10 ans et plus selon le niveau d’instruction')

        df_long['sexe'] = sexe
        df_long['milieu'] = milieu
        df_long['annee'] = annee
        df_long['unite'] = unite
        df_long['feuille'] = feuille

        dfs_long.append(df_long)
        print(f"✅ Feuille '{feuille}' traitée.\n")

    except Exception as e:
        print(f"❌ Erreur dans la feuille '{feuille}': {e}\n")

if dfs_long:
    df_final = pd.concat(dfs_long, ignore_index=True)
    print("✅ Fusion terminée. Exemple :\n")
    print(df_final.head())
    df_final.to_excel("resultat_educ_auto.xlsx", index=False)
    print("📁 Données enregistrées dans 'resultat_educ_auto.xlsx'")

    with pd.option_context('display.max_rows', None, 'display.max_columns', None):
        print(df_final)
else:
    print("❌ Aucune donnée traitée.")
df_final.to_csv("instruction_1994.csv", index=False, encoding='utf-8-sig')
# Out:
# 📄 Traitement de la feuille : T72-55
# ✅ Feuille 'T72-55' traitée.
#
# 📄 Traitement de la feuille : T72-56
# ✅ Feuille 'T72-56' traitée.
#
# 📄 Traitement de la feuille : T72-57
# ✅ Feuille 'T72-57' traitée.
#
# 📄 Traitement de la feuille : T72-58
# ✅ Feuille 'T72-58' traitée.
#
# 📄 Traitement de la feuille : T72-59
# ✅ Feuille 'T72-59' traitée.
#
# 📄 Traitement de la feuille : T72-60
# ✅ Feuille 'T72-60' traitée.
#
# 📄 Traitement de la feuille : T72-61
# ✅ Feuille 'T72-61' traitée.
#
# 📄 Traitement de la feuille : T72-62
# ✅ Feuille 'T72-62' traitée.
#
# 📄 Traitement de la feuille : T72-63
# ✅ Feuille 'T72-63' traitée.
#
# 📄 Traitement de la feuille : T72-64
# ✅ Feuille 'T72-64' traitée.
#
# 📄 Traitement de la feuille : T72-65
# ✅ Feuille 'T72-65' traitée.
#
# 📄 Traitement de la feuille : T72-66
# ✅ Feuille 'T72-66' traitée.
#
# 📄 Traitement de la feuille : T72-67
# ✅ Feuille 'T72-67' traitée.
#
# 📄 Traitement de la feuille : T72-68
# ✅ Feuille 'T72-68' traitée.
#
# 📄 Traitement de la feuille : T72-69
# ✅ Feuille 'T72-69' traitée.
#
# 📄 Traitement de la feuille : T72-70
# ✅ Feuille 'T72-70' traitée.
#
# 📄 Traitement de la feuille : T72-71
# ✅ Feuille 'T72-71' traitée.
#
# 📄 Traitement de la feuille : T72-72
# ✅ Feuille 'T72-72' traitée.
#
# 📄 Traitement de la feuille : T72-73
# ✅ Feuille 'T72-73' traitée.
#
# 📄 Traitement de la feuille : T72-74
# ✅ Feuille 'T72-74' traitée.
#
# 📄 Traitement de la feuille : T72-75
# ✅ Feuille 'T72-75' traitée.
#
# 📄 Traitement de la feuille : T72-76
# ✅ Feuille 'T72-76' traitée.
#
# 📄 Traitement de la feuille : T72-77
# ✅ Feuille 'T72-77' traitée.
#
# 📄 Traitement de la feuille : T72-78
# ✅ Feuille 'T72-78' traitée.
#
# 📄 Traitement de la feuille : T72-79
# ✅ Feuille 'T72-79' traitée.
#
# 📄 Traitement de la feuille : T72-80
# ✅ Feuille 'T72-80' traitée.
#
# 📄 Traitement de la feuille : T72-81
# ✅ Feuille 'T72-81' traitée.
#
# 📄 Traitement de la feuille : T72-82
# ✅ Feuille 'T72-82' traitée.
#
# 📄 Traitement de la feuille : T72-83
# ✅ Feuille 'T72-83' traitée.
#
# 📄 Traitement de la feuille : T72-84
# ✅ Feuille 'T72-84' traitée.
#
# 📄 Traitement de la feuille : T72-85
# ✅ Feuille 'T72-85' traitée.
#
# 📄 Traitement de la feuille : T72-86
# ✅ Feuille 'T72-86' traitée.
#
# 📄 Traitement de la feuille : T72-87
# ✅ Feuille 'T72-87' traitée.
#
# 📄 Traitement de la feuille : T72-88
# ✅ Feuille 'T72-88' traitée.
#
# 📄 Traitement de la feuille : T72-89
# ✅ Feuille 'T72-89' traitée.
#
# ✅ Fusion terminée. Exemple :
#
#                                           indicateur gouvernorat groupe_d_age  \
# 0  Population âgée de 10 ans et plus selon le niv...           .       10--14
# 1  Population âgée de 10 ans et plus selon le niv...           .        15-19
# 2  Population âgée de 10 ans et plus selon le niv...           .        20-24
# 3  Population âgée de 10 ans et plus selon le niv...           .        25-29
# 4  Population âgée de 10 ans et plus selon le niv...           .        30-34
#
#   niveaux_d_etude valeur      sexe    milieu  annee     unite feuille
# 0    non_declares   6147  Ensemble  Ensemble   1994  effectif  T72-55
# 1    non_declares   3021  Ensemble  Ensemble   1994  effectif  T72-55
# 2    non_declares   2049  Ensemble  Ensemble   1994  effectif  T72-55
# 3    non_declares   2062  Ensemble  Ensemble   1994  effectif  T72-55
# 4    non_declares   1867  Ensemble  Ensemble   1994  effectif  T72-55
# 📁 Données enregistrées dans 'resultat_educ_auto.xlsx'
#                                              indicateur    gouvernorat  \
# 0     Population âgée de 10 ans et plus selon le niv...              .
# 1     Population âgée de 10 ans et plus selon le niv...              .
# 2     Population âgée de 10 ans et plus selon le niv...              .
# 3     Population âgée de 10 ans et plus selon le niv...              .
# 4     Population âgée de 10 ans et plus selon le niv...              .
# 5     Population âgée de 10 ans et plus selon le niv...              .
# 6     Population âgée de 10 ans et plus selon le niv...              .
# 7     Population âgée de 10 ans et plus selon le niv...              .
# 8     Population âgée de 10 ans et plus selon le niv...              .
# 9     Population âgée de 10 ans et plus selon le niv...              .
# 10    Population âgée de 10 ans et plus selon le niv...              .
# 11    Population âgée de 10 ans et plus selon le niv...              .
# 12    Population âgée de 10 ans et plus selon le niv...              .
# 13    Population âgée de 10 ans et plus selon le niv...              .
# 14    Population âgée de 10 ans et plus selon le niv...              .
# 15    Population âgée de 10 ans et plus selon le niv...              .
# 16    Population âgée de 10 ans et plus selon le niv...              .
# 17    Population âgée de 10 ans et plus selon le niv...              .
# 18    Population âgée de 10 ans et plus selon le niv...              .
# 19    Population âgée de 10 ans et plus selon le niv...              .
# 20    Population âgée de 10 ans et plus selon le niv...              .
# 21    Population âgée de 10 ans et plus selon le niv...              .
# 22    Population âgée de 10 ans et plus selon le niv...              .
# 23    Population âgée de 10 ans et plus selon le niv...              .
# 24    Population âgée de 10 ans et plus selon le niv...              .
# 25    Population âgée de 10 ans et plus selon le niv...              .
# 26    Population âgée de 10 ans et plus selon le niv...              .
# 27    Population âgée de 10 ans et plus selon le niv...              .
# 28    Population âgée de 10 ans et plus selon le niv...              .
# 29    Population âgée de 10 ans et plus selon le niv...              .
# 30    Population âgée de 10 ans et plus selon le niv...              .
# 31    Population âgée de 10 ans et plus selon le niv...              .
# 32    Population âgée de 10 ans et plus selon le niv...              .
# 33    Population âgée de 10 ans et plus selon le niv...              .
# 34    Population âgée de 10 ans et plus selon le niv...              .
# 35    Population âgée de 10 ans et plus selon le niv...              .
# 36    Population âgée de 10 ans et plus selon le niv...              .
# 37    Population âgée de 10 ans et plus selon le niv...              .
# 38    Population âgée de 10 ans et plus selon le niv...              .
# 39    Population âgée de 10 ans et plus selon le niv...              .
# 40    Population âgée de 10 ans et plus selon le niv...              .
# 41    Population âgée de 10 ans et plus selon le niv...              .
# 42    Population âgée de 10 ans et plus selon le niv...              .
# 43    Population âgée de 10 ans et plus selon le niv...              .
# 44    Population âgée de 10 ans et plus selon le niv...              .
# 45    Population âgée de 10 ans et plus selon le niv...              .
# 46    Population âgée de 10 ans et plus selon le niv...              .
# 47    Population âgée de 10 ans et plus selon le niv...              .
# 48    Population âgée de 10 ans et plus selon le niv...              .
# 49    Population âgée de 10 ans et plus selon le niv...              .
# 50    Population âgée de 10 ans et plus selon le niv...              .
# 51    Population âgée de 10 ans et plus selon le niv...              .
# 52    Population âgée de 10 ans et plus selon le niv...              .
# 53    Population âgée de 10 ans et plus selon le niv...              .
# 54    Population âgée de 10 ans et plus selon le niv...              .
# 55    Population âgée de 10 ans et plus selon le niv...              .
# 56    Population âgée de 10 ans et plus selon le niv...              .
# 57    Population âgée de 10 ans et plus selon le niv...              .
# 58    Population âgée de 10 ans et plus selon le niv...              .
# 59    Population âgée de 10 ans et plus selon le niv...              .
# 60    Population âgée de 10 ans et plus selon le niv...              .
# 61    Population âgée de 10 ans et plus selon le niv...              .
# 62    Population âgée de 10 ans et plus selon le niv...              .
# 63    Population âgée de 10 ans et plus selon le niv...              .
# 64    Population âgée de 10 ans et plus selon le niv...              .
# 65    Population âgée de 10 ans et plus selon le niv...              .
# 66    Population âgée de 10 ans et plus selon le niv...              .
# 67    Population âgée de 10 ans et plus selon le niv...              .
# 68    Population âgée de 10 ans et plus selon le niv...              .
# 69    Population âgée de 10 ans et plus selon le niv...              .
# 70    Population âgée de 10 ans et plus selon le niv...              .
# 71    Population âgée de 10 ans et plus selon le niv...              .
# 72    Population âgée de 10 ans et plus selon le niv...              .
# 73    Population âgée de 10 ans et plus selon le niv...              .
# 74    Population âgée de 10 ans et plus selon le niv...              .
# 75    Population âgée de 10 ans et plus selon le niv...              .
# 76    Population âgée de 10 ans et plus selon le niv...              .
# 77    Population âgée de 10 ans et plus selon le niv...              .
# 78    Population âgée de 10 ans et plus selon le niv...              .
# 79    Population âgée de 10 ans et plus selon le niv...              .
# 80    Population âgée de 10 ans et plus selon le niv...              .
# 81    Population âgée de 10 ans et plus selon le niv...              .
# 82    Population âgée de 10 ans et plus selon le niv...              .
# 83    Population âgée de 10 ans et plus selon le niv...              .
# 84    Population âgée de 10 ans et plus selon le niv...              .
# 85    Population âgée de 10 ans et plus selon le niv...              .
# 86    Population âgée de 10 ans et plus selon le niv...              .
# 87    Population âgée de 10 ans et plus selon le niv...              .
# 88    Population âgée de 10 ans et plus selon le niv...              .
# 89    Population âgée de 10 ans et plus selon le niv...              .
# 90    Population âgée de 10 ans et plus selon le niv...              .
# 91    Population âgée de 10 ans et plus selon le niv...              .
# 92    Population âgée de 10 ans et plus selon le niv...              .
# 93    Population âgée de 10 ans et plus selon le niv...              .
# 94    Population âgée de 10 ans et plus selon le niv...              .
# 95    Population âgée de 10 ans et plus selon le niv...              .
# 96    Population âgée de 10 ans et plus selon le niv...              .
# 97    Population âgée de 10 ans et plus selon le niv...              .
# 98    Population âgée de 10 ans et plus selon le niv...              .
# 99    Population âgée de 10 ans et plus selon le niv...              .
# 100   Population âgée de 10 ans et plus selon le niv...              .
# 101   Population âgée de 10 ans et plus selon le niv...              .
# 102   Population âgée de 10 ans et plus selon le niv...              .
# 103   Population âgée de 10 ans et plus selon le niv...              .
# 104   Population âgée de 10 ans et plus selon le niv...              .
# 105   Population âgée de 10 ans et plus selon le niv...              .
# 106   Population âgée de 10 ans et plus selon le niv...              .
# 107   Population âgée de 10 ans et plus selon le niv...              .
# 108   Population âgée de 10 ans et plus selon le niv...              .
# 109   Population âgée de 10 ans et plus selon le niv...              .
# 110   Population âgée de 10 ans et plus selon le niv...              .
# 111   Population âgée de 10 ans et plus selon le niv...              .
# 112   Population âgée de 10 ans et plus selon le niv...              .
# 113   Population âgée de 10 ans et plus selon le niv...              .
# 114   Population âgée de 10 ans et plus selon le niv...              .
# 115   Population âgée de 10 ans et plus selon le niv...              .
# 116   Population âgée de 10 ans et plus selon le niv...              .
# 117   Population âgée de 10 ans et plus selon le niv...              .
# 118   Population âgée de 10 ans et plus selon le niv...              .
# 119   Population âgée de 10 ans et plus selon le niv...              .
# 120   Population âgée de 10 ans et plus selon le niv...              .
# 121   Population âgée de 10 ans et plus selon le niv...              .
# 122   Population âgée de 10 ans et plus selon le niv...              .
# 123   Population âgée de 10 ans et plus selon le niv...              .
# 124   Population âgée de 10 ans et plus selon le niv...              .
# 125   Population âgée de 10 ans et plus selon le niv...              .
# 126   Population âgée de 10 ans et plus selon le niv...              .
# 127   Population âgée de 10 ans et plus selon le niv...              .
# 128   Population âgée de 10 ans et plus selon le niv...              .
# 129   Population âgée de 10 ans et plus selon le niv...              .
# 130   Population âgée de 10 ans et plus selon le niv...              .
# 131   Population âgée de 10 ans et plus selon le niv...              .
# 132   Population âgée de 10 ans et plus selon le niv...              .
# 133   Population âgée de 10 ans et plus selon le niv...              .
# 134   Population âgée de 10 ans et plus selon le niv...              .
# 135   Population âgée de 10 ans et plus selon le niv...              .
# 136   Population âgée de 10 ans et plus selon le niv...              .
# 137   Population âgée de 10 ans et plus selon le niv...              .
# 138   Population âgée de 10 ans et plus selon le niv...              .
# 139   Population âgée de 10 ans et plus selon le niv...              .
# 140   Population âgée de 10 ans et plus selon le niv...              .
# 141   Population âgée de 10 ans et plus selon le niv...              .
# 142   Population âgée de 10 ans et plus selon le niv...              .
# 143   Population âgée de 10 ans et plus selon le niv...              .
# 144   Population âgée de 10 ans et plus selon le niv...              .
# 145   Population âgée de 10 ans et plus selon le niv...              .
# 146   Population âgée de 10 ans et plus selon le niv...              .
# 147   Population âgée de 10 ans et plus selon le niv...              .
# 148   Population âgée de 10 ans et plus selon le niv...              .
# 149   Population âgée de 10 ans et plus selon le niv...              .
# 150   Population âgée de 10 ans et plus selon le niv...              .
# 151   Population âgée de 10 ans et plus selon le niv...              .
# 152   Population âgée de 10 ans et plus selon le niv...              .
# 153   Population âgée de 10 ans et plus selon le niv...              .
# 154   Population âgée de 10 ans et plus selon le niv...              .
# 155   Population âgée de 10 ans et plus selon le niv...              .
# 156   Population âgée de 10 ans et plus selon le niv...              .
# 157   Population âgée de 10 ans et plus selon le niv...              .
# 158   Population âgée de 10 ans et plus selon le niv...              .
# 159   Population âgée de 10 ans et plus selon le niv...              .
# 160   Population âgée de 10 ans et plus selon le niv...              .
# 161   Population âgée de 10 ans et plus selon le niv...              .
# 162   Population âgée de 10 ans et plus selon le niv...              .
# 163   Population âgée de 10 ans et plus selon le niv...              .
# 164   Population âgée de 10 ans et plus selon le niv...              .
# 165   Population âgée de 10 ans et plus selon le niv...              .
# 166   Population âgée de 10 ans et plus selon le niv...              .
# 167   Population âgée de 10 ans et plus selon le niv...              .
# 168   Population âgée de 10 ans et plus selon le niv...              .
# 169   Population âgée de 10 ans et plus selon le niv...              .
# 170   Population âgée de 10 ans et plus selon le niv...              .
# 171   Population âgée de 10 ans et plus selon le niv...              .
# 172   Population âgée de 10 ans et plus selon le niv...              .
# 173   Population âgée de 10 ans et plus selon le niv...              .
# 174   Population âgée de 10 ans et plus selon le niv...              .
# 175   Population âgée de 10 ans et plus selon le niv...              .
# 176   Population âgée de 10 ans et plus selon le niv...              .
# 177   Population âgée de 10 ans et plus selon le niv...              .
# 178   Population âgée de 10 ans et plus selon le niv...              .
# 179   Population âgée de 10 ans et plus selon le niv...              .
# 180   Population âgée de 10 ans et plus selon le niv...              .
# 181   Population âgée de 10 ans et plus selon le niv...              .
# 182   Population âgée de 10 ans et plus selon le niv...              .
# 183   Population âgée de 10 ans et plus selon le niv...              .
# 184   Population âgée de 10 ans et plus selon le niv...              .
# 185   Population âgée de 10 ans et plus selon le niv...              .
# 186   Population âgée de 10 ans et plus selon le niv...              .
# 187   Population âgée de 10 ans et plus selon le niv...              .
# 188   Population âgée de 10 ans et plus selon le niv...              .
# 189   Population âgée de 10 ans et plus selon le niv...              .
# 190   Population âgée de 10 ans et plus selon le niv...              .
# 191   Population âgée de 10 ans et plus selon le niv...              .
# 192   Population âgée de 10 ans et plus selon le niv...              .
# 193   Population âgée de 10 ans et plus selon le niv...              .
# 194   Population âgée de 10 ans et plus selon le niv...              .
# 195   Population âgée de 10 ans et plus selon le niv...              .
# 196   Population âgée de 10 ans et plus selon le niv...              .
# 197   Population âgée de 10 ans et plus selon le niv...              .
# 198   Population âgée de 10 ans et plus selon le niv...              .
# 199   Population âgée de 10 ans et plus selon le niv...              .
# 200   Population âgée de 10 ans et plus selon le niv...              .
# 201   Population âgée de 10 ans et plus selon le niv...              .
# 202   Population âgée de 10 ans et plus selon le niv...              .
# 203   Population âgée de 10 ans et plus selon le niv...              .
# 204   Population âgée de 10 ans et plus selon le niv...              .
# 205   Population âgée de 10 ans et plus selon le niv...              .
# 206   Population âgée de 10 ans et plus selon le niv...              .
# 207   Population âgée de 10 ans et plus selon le niv...              .
# 208   Population âgée de 10 ans et plus selon le niv...              .
# 209   Population âgée de 10 ans et plus selon le niv...              .
# 210   Population âgée de 10 ans et plus selon le niv...              .
# 211   Population âgée de 10 ans et plus selon le niv...              .
# 212   Population âgée de 10 ans et plus selon le niv...              .
# 213   Population âgée de 10 ans et plus selon le niv...              .
# 214   Population âgée de 10 ans et plus selon le niv...              .
# 215   Population âgée de 10 ans et plus selon le niv...              .
# 216   Population âgée de 10 ans et plus selon le niv...              .
# 217   Population âgée de 10 ans et plus selon le niv...              .
# 218   Population âgée de 10 ans et plus selon le niv...              .
# 219   Population âgée de 10 ans et plus selon le niv...              .
# 220   Population âgée de 10 ans et plus selon le niv...              .
# 221   Population âgée de 10 ans et plus selon le niv...              .
# 222   Population âgée de 10 ans et plus selon le niv...              .
# 223   Population âgée de 10 ans et plus selon le niv...              .
# 224   Population âgée de 10 ans et plus selon le niv...              .
# 225   Population âgée de 10 ans et plus selon le niv...              .
# 226   Population âgée de 10 ans et plus selon le niv...              .
# 227   Population âgée de 10 ans et plus selon le niv...              .
# 228   Population âgée de 10 ans et plus selon le niv...              .
# 229   Population âgée de 10 ans et plus selon le niv...              .
# 230   Population âgée de 10 ans et plus selon le niv...              .
# 231   Population âgée de 10 ans et plus selon le niv...              .
# 232   Population âgée de 10 ans et plus selon le niv...              .
# 233   Population âgée de 10 ans et plus selon le niv...              .
# 234   Population âgée de 10 ans et plus selon le niv...              .
# 235   Population âgée de 10 ans et plus selon le niv...              .
# 236   Population âgée de 10 ans et plus selon le niv...              .
# 237   Population âgée de 10 ans et plus selon le niv...              .
# 238   Population âgée de 10 ans et plus selon le niv...              .
# 239   Population âgée de 10 ans et plus selon le niv...              .
# 240   Population âgée de 10 ans et plus selon le niv...              .
# 241   Population âgée de 10 ans et plus selon le niv...              .
# 242   Population âgée de 10 ans et plus selon le niv...              .
# 243   Population âgée de 10 ans et plus selon le niv...              .
# 244   Population âgée de 10 ans et plus selon le niv...              .
# 245   Population âgée de 10 ans et plus selon le niv...              .
# 246   Population âgée de 10 ans et plus selon le niv...              .
# 247   Population âgée de 10 ans et plus selon le niv...              .
# 248   Population âgée de 10 ans et plus selon le niv...              .
# 249   Population âgée de 10 ans et plus selon le niv...              .
# 250   Population âgée de 10 ans et plus selon le niv...              .
# 251   Population âgée de 10 ans et plus selon le niv...              .
# 252   Population âgée de 10 ans et plus selon le niv...              .
# 253   Population âgée de 10 ans et plus selon le niv...              .
# 254   Population âgée de 10 ans et plus selon le niv...              .
# 255   Population âgée de 10 ans et plus selon le niv...              .
# 256   Population âgée de 10 ans et plus selon le niv...              .
# 257   Population âgée de 10 ans et plus selon le niv...              .
# 258   Population âgée de 10 ans et plus selon le niv...              .
# 259   Population âgée de 10 ans et plus selon le niv...              .
# 260   Population âgée de 10 ans et plus selon le niv...              .
# 261   Population âgée de 10 ans et plus selon le niv...              .
# 262   Population âgée de 10 ans et plus selon le niv...              .
# 263   Population âgée de 10 ans et plus selon le niv...              .
# 264   Population âgée de 10 ans et plus selon le niv...              .
# 265   Population âgée de 10 ans et plus selon le niv...              .
# 266   Population âgée de 10 ans et plus selon le niv...              .
# 267   Population âgée de 10 ans et plus selon le niv...              .
# 268   Population âgée de 10 ans et plus selon le niv...              .
# 269   Population âgée de 10 ans et plus selon le niv...              .
# 270   Population âgée de 10 ans et plus selon le niv...              .
# 271   Population âgée de 10 ans et plus selon le niv...              .
# 272   Population âgée de 10 ans et plus selon le niv...              .
# 273   Population âgée de 10 ans et plus selon le niv...              .
# 274   Population âgée de 10 ans et plus selon le niv...              .
# 275   Population âgée de 10 ans et plus selon le niv...              .
# 276   Population âgée de 10 ans et plus selon le niv...              .
# 277   Population âgée de 10 ans et plus selon le niv...              .
# 278   Population âgée de 10 ans et plus selon le niv...              .
# 279   Population âgée de 10 ans et plus selon le niv...              .
# 280   Population âgée de 10 ans et plus selon le niv...              .
# 281   Population âgée de 10 ans et plus selon le niv...              .
# 282   Population âgée de 10 ans et plus selon le niv...              .
# 283   Population âgée de 10 ans et plus selon le niv...              .
# 284   Population âgée de 10 ans et plus selon le niv...              .
# 285   Population âgée de 10 ans et plus selon le niv...              .
# 286   Population âgée de 10 ans et plus selon le niv...              .
# 287   Population âgée de 10 ans et plus selon le niv...              .
# 288   Population âgée de 10 ans et plus selon le niv...              .
# 289   Population âgée de 10 ans et plus selon le niv...              .
# 290   Population âgée de 10 ans et plus selon le niv...              .
# 291   Population âgée de 10 ans et plus selon le niv...              .
# 292   Population âgée de 10 ans et plus selon le niv...              .
# 293   Population âgée de 10 ans et plus selon le niv...              .
# 294   Population âgée de 10 ans et plus selon le niv...              .
# 295   Population âgée de 10 ans et plus selon le niv...              .
# 296   Population âgée de 10 ans et plus selon le niv...              .
# 297   Population âgée de 10 ans et plus selon le niv...              .
# 298   Population âgée de 10 ans et plus selon le niv...              .
# 299   Population âgée de 10 ans et plus selon le niv...              .
# 300   Population âgée de 10 ans et plus selon le niv...              .
# 301   Population âgée de 10 ans et plus selon le niv...              .
# 302   Population âgée de 10 ans et plus selon le niv...              .
# 303   Population âgée de 10 ans et plus selon le niv...              .
# 304   Population âgée de 10 ans et plus selon le niv...              .
# 305   Population âgée de 10 ans et plus selon le niv...              .
# 306   Population âgée de 10 ans et plus selon le niv...              .
# 307   Population âgée de 10 ans et plus selon le niv...              .
# 308   Population âgée de 10 ans et plus selon le niv...              .
# 309   Population âgée de 10 ans et plus selon le niv...              .
# 310   Population âgée de 10 ans et plus selon le niv...              .
# 311   Population âgée de 10 ans et plus selon le niv...              .
# 312   Population âgée de 10 ans et plus selon le niv...              .
# 313   Population âgée de 10 ans et plus selon le niv...              .
# 314   Population âgée de 10 ans et plus selon le niv...              .
# 315   Population âgée de 10 ans et plus selon le niv...              .
# 316   Population âgée de 10 ans et plus selon le niv...              .
# 317   Population âgée de 10 ans et plus selon le niv...              .
# 318   Population âgée de 10 ans et plus selon le niv...              .
# 319   Population âgée de 10 ans et plus selon le niv...              .
# 320   Population âgée de 10 ans et plus selon le niv...              .
# 321   Population âgée de 10 ans et plus selon le niv...              .
# 322   Population âgée de 10 ans et plus selon le niv...              .
# 323   Population âgée de 10 ans et plus selon le niv...              .
# 324   Population âgée de 10 ans et plus selon le niv...              .
# 325   Population âgée de 10 ans et plus selon le niv...              .
# 326   Population âgée de 10 ans et plus selon le niv...              .
# 327   Population âgée de 10 ans et plus selon le niv...              .
# 328   Population âgée de 10 ans et plus selon le niv...              .
# 329   Population âgée de 10 ans et plus selon le niv...              .
# 330   Population âgée de 10 ans et plus selon le niv...              .
# 331   Population âgée de 10 ans et plus selon le niv...              .
# 332   Population âgée de 10 ans et plus selon le niv...              .
# 333   Population âgée de 10 ans et plus selon le niv...              .
# 334   Population âgée de 10 ans et plus selon le niv...              .
# 335   Population âgée de 10 ans et plus selon le niv...              .
# 336   Population âgée de 10 ans et plus selon le niv...              .
# 337   Population âgée de 10 ans et plus selon le niv...              .
# 338   Population âgée de 10 ans et plus selon le niv...              .
# 339   Population âgée de 10 ans et plus selon le niv...              .
# 340   Population âgée de 10 ans et plus selon le niv...              .
# 341   Population âgée de 10 ans et plus selon le niv...              .
# 342   Population âgée de 10 ans et plus selon le niv...              .
# 343   Population âgée de 10 ans et plus selon le niv...              .
# 344   Population âgée de 10 ans et plus selon le niv...              .
# 345   Population âgée de 10 ans et plus selon le niv...              .
# 346   Population âgée de 10 ans et plus selon le niv...              .
# 347   Population âgée de 10 ans et plus selon le niv...              .
# 348   Population âgée de 10 ans et plus selon le niv...              .
# 349   Population âgée de 10 ans et plus selon le niv...              .
# 350   Population âgée de 10 ans et plus selon le niv...              .
# 351   Population âgée de 10 ans et plus selon le niv...              .
# 352   Population âgée de 10 ans et plus selon le niv...              .
# 353   Population âgée de 10 ans et plus selon le niv...              .
# 354   Population âgée de 10 ans et plus selon le niv...              .
# 355   Population âgée de 10 ans et plus selon le niv...              .
# 356   Population âgée de 10 ans et plus selon le niv...              .
# 357   Population âgée de 10 ans et plus selon le niv...              .
# 358   Population âgée de 10 ans et plus selon le niv...              .
# 359   Population âgée de 10 ans et plus selon le niv...              .
# 360   Population âgée de 10 ans et plus selon le niv...              .
# 361   Population âgée de 10 ans et plus selon le niv...              .
# 362   Population âgée de 10 ans et plus selon le niv...              .
# 363   Population âgée de 10 ans et plus selon le niv...              .
# 364   Population âgée de 10 ans et plus selon le niv...              .
# 365   Population âgée de 10 ans et plus selon le niv...              .
# 366   Population âgée de 10 ans et plus selon le niv...              .
# 367   Population âgée de 10 ans et plus selon le niv...              .
# 368   Population âgée de 10 ans et plus selon le niv...              .
# 369   Population âgée de 10 ans et plus selon le niv...              .
# 370   Population âgée de 10 ans et plus selon le niv...              .
# 371   Population âgée de 10 ans et plus selon le niv...              .
# 372   Population âgée de 10 ans et plus selon le niv...              .
# 373   Population âgée de 10 ans et plus selon le niv...              .
# 374   Population âgée de 10 ans et plus selon le niv...              .
# 375   Population âgée de 10 ans et plus selon le niv...              .
# 376   Population âgée de 10 ans et plus selon le niv...              .
# 377   Population âgée de 10 ans et plus selon le niv...              .
# 378   Population âgée de 10 ans et plus selon le niv...              .
# 379   Population âgée de 10 ans et plus selon le niv...              .
# 380   Population âgée de 10 ans et plus selon le niv...              .
# 381   Population âgée de 10 ans et plus selon le niv...              .
# 382   Population âgée de 10 ans et plus selon le niv...              .
# 383   Population âgée de 10 ans et plus selon le niv...              .
# 384   Population âgée de 10 ans et plus selon le niv...              .
# 385   Population âgée de 10 ans et plus selon le niv...              .
# 386   Population âgée de 10 ans et plus selon le niv...              .
# 387   Population âgée de 10 ans et plus selon le niv...              .
# 388   Population âgée de 10 ans et plus selon le niv...              .
# 389   Population âgée de 10 ans et plus selon le niv...              .
# 390   Population âgée de 10 ans et plus selon le niv...              .
# 391   Population âgée de 10 ans et plus selon le niv...              .
# 392   Population âgée de 10 ans et plus selon le niv...              .
# 393   Population âgée de 10 ans et plus selon le niv...              .
# 394   Population âgée de 10 ans et plus selon le niv...              .
# 395   Population âgée de 10 ans et plus selon le niv...              .
# 396   Population âgée de 10 ans et plus selon le niv...              .
# 397   Population âgée de 10 ans et plus selon le niv...              .
# 398   Population âgée de 10 ans et plus selon le niv...              .
# 399   Population âgée de 10 ans et plus selon le niv...              .
# 400   Population âgée de 10 ans et plus selon le niv...              .
# 401   Population âgée de 10 ans et plus selon le niv...              .
# 402   Population âgée de 10 ans et plus selon le niv...              .
# 403   Population âgée de 10 ans et plus selon le niv...              .
# 404   Population âgée de 10 ans et plus selon le niv...              .
# 405   Population âgée de 10 ans et plus selon le niv...              .
# 406   Population âgée de 10 ans et plus selon le niv...              .
# 407   Population âgée de 10 ans et plus selon le niv...              .
# 408   Population âgée de 10 ans et plus selon le niv...              .
# 409   Population âgée de 10 ans et plus selon le niv...              .
# 410   Population âgée de 10 ans et plus selon le niv...              .
# 411   Population âgée de 10 ans et plus selon le niv...              .
# 412   Population âgée de 10 ans et plus selon le niv...              .
# 413   Population âgée de 10 ans et plus selon le niv...              .
# 414   Population âgée de 10 ans et plus selon le niv...              .
# 415   Population âgée de 10 ans et plus selon le niv...              .
# 416   Population âgée de 10 ans et plus selon le niv...              .
# 417   Population âgée de 10 ans et plus selon le niv...              .
# 418   Population âgée de 10 ans et plus selon le niv...              .
# 419   Population âgée de 10 ans et plus selon le niv...              .
# 420   Population âgée de 10 ans et plus selon le niv...              .
# 421   Population âgée de 10 ans et plus selon le niv...              .
# 422   Population âgée de 10 ans et plus selon le niv...              .
# 423   Population âgée de 10 ans et plus selon le niv...              .
# 424   Population âgée de 10 ans et plus selon le niv...              .
# 425   Population âgée de 10 ans et plus selon le niv...              .
# 426   Population âgée de 10 ans et plus selon le niv...              .
# 427   Population âgée de 10 ans et plus selon le niv...              .
# 428   Population âgée de 10 ans et plus selon le niv...              .
# 429   Population âgée de 10 ans et plus selon le niv...              .
# 430   Population âgée de 10 ans et plus selon le niv...              .
# 431   Population âgée de 10 ans et plus selon le niv...              .
# 432   Population âgée de 10 ans et plus selon le niv...              .
# 433   Population âgée de 10 ans et plus selon le niv...              .
# 434   Population âgée de 10 ans et plus selon le niv...              .
# 435   Population âgée de 10 ans et plus selon le niv...              .
# 436   Population âgée de 10 ans et plus selon le niv...              .
# 437   Population âgée de 10 ans et plus selon le niv...              .
# 438   Population âgée de 10 ans et plus selon le niv...              .
# 439   Population âgée de 10 ans et plus selon le niv...              .
# 440   Population âgée de 10 ans et plus selon le niv...              .
# 441   Population âgée de 10 ans et plus selon le niv...              .
# 442   Population âgée de 10 ans et plus selon le niv...              .
# 443   Population âgée de 10 ans et plus selon le niv...              .
# 444   Population âgée de 10 ans et plus selon le niv...              .
# 445   Population âgée de 10 ans et plus selon le niv...              .
# 446   Population âgée de 10 ans et plus selon le niv...              .
# 447   Population âgée de 10 ans et plus selon le niv...              .
# 448   Population âgée de 10 ans et plus selon le niv...              .
# 449   Population âgée de 10 ans et plus selon le niv...              .
# 450   Population âgée de 10 ans et plus selon le niv...              .
# 451   Population âgée de 10 ans et plus selon le niv...              .
# 452   Population âgée de 10 ans et plus selon le niv...              .
# 453   Population âgée de 10 ans et plus selon le niv...              .
# 454   Population âgée de 10 ans et plus selon le niv...              .
# 455   Population âgée de 10 ans et plus selon le niv...              .
# 456   Population âgée de 10 ans et plus selon le niv...              .
# 457   Population âgée de 10 ans et plus selon le niv...              .
# 458   Population âgée de 10 ans et plus selon le niv...              .
# 459   Population âgée de 10 ans et plus selon le niv...              .
# 460   Population âgée de 10 ans et plus selon le niv...              .
# 461   Population âgée de 10 ans et plus selon le niv...              .
# 462   Population âgée de 10 ans et plus selon le niv...              .
# 463   Population âgée de 10 ans et plus selon le niv...              .
# 464   Population âgée de 10 ans et plus selon le niv...              .
# 465   Population âgée de 10 ans et plus selon le niv...              .
# 466   Population âgée de 10 ans et plus selon le niv...              .
# 467   Population âgée de 10 ans et plus selon le niv...              .
# 468   Population âgée de 10 ans et plus selon le niv...              .
# 469   Population âgée de 10 ans et plus selon le niv...              .
# 470   Population âgée de 10 ans et plus selon le niv...              .
# 471   Population âgée de 10 ans et plus selon le niv...              .
# 472   Population âgée de 10 ans et plus selon le niv...              .
# 473   Population âgée de 10 ans et plus selon le niv...              .
# 474   Population âgée de 10 ans et plus selon le niv...              .
# 475   Population âgée de 10 ans et plus selon le niv...              .
# 476   Population âgée de 10 ans et plus selon le niv...              .
# 477   Population âgée de 10 ans et plus selon le niv...              .
# 478   Population âgée de 10 ans et plus selon le niv...              .
# 479   Population âgée de 10 ans et plus selon le niv...              .
# 480   Population âgée de 10 ans et plus selon le niv...              .
# 481   Population âgée de 10 ans et plus selon le niv...              .
# 482   Population âgée de 10 ans et plus selon le niv...              .
# 483   Population âgée de 10 ans et plus selon le niv...              .
# 484   Population âgée de 10 ans et plus selon le niv...              .
# 485   Population âgée de 10 ans et plus selon le niv...              .
# 486   Population âgée de 10 ans et plus selon le niv...              .
# 487   Population âgée de 10 ans et plus selon le niv...              .
# 488   Population âgée de 10 ans et plus selon le niv...              .
# 489   Population âgée de 10 ans et plus selon le niv...              .
# 490   Population âgée de 10 ans et plus selon le niv...              .
# 491   Population âgée de 10 ans et plus selon le niv...              .
# 492   Population âgée de 10 ans et plus selon le niv...              .
# 493   Population âgée de 10 ans et plus selon le niv...              .
# 494   Population âgée de 10 ans et plus selon le niv...              .
# 495   Population âgée de 10 ans et plus selon le niv...              .
# 496   Population âgée de 10 ans et plus selon le niv...              .
# 497   Population âgée de 10 ans et plus selon le niv...              .
# 498   Population âgée de 10 ans et plus selon le niv...              .
# 499   Population âgée de 10 ans et plus selon le niv...              .
# 500   Population âgée de 10 ans et plus selon le niv...              .
# 501   Population âgée de 10 ans et plus selon le niv...              .
# 502   Population âgée de 10 ans et plus selon le niv...              .
# 503   Population âgée de 10 ans et plus selon le niv...              .
# 504   Population âgée de 10 ans et plus selon le niv...              .
# 505   Population âgée de 10 ans et plus selon le niv...              .
# 506   Population âgée de 10 ans et plus selon le niv...              .
# 507   Population âgée de 10 ans et plus selon le niv...              .
# 508   Population âgée de 10 ans et plus selon le niv...              .
# 509   Population âgée de 10 ans et plus selon le niv...              .
# 510   Population âgée de 10 ans et plus selon le niv...              .
# 511   Population âgée de 10 ans et plus selon le niv...              .
# 512   Population âgée de 10 ans et plus selon le niv...              .
# 513   Population âgée de 10 ans et plus selon le niv...              .
# 514   Population âgée de 10 ans et plus selon le niv...              .
# 515   Population âgée de 10 ans et plus selon le niv...              .
# 516   Population âgée de 10 ans et plus selon le niv...              .
# 517   Population âgée de 10 ans et plus selon le niv...              .
# 518   Population âgée de 10 ans et plus selon le niv...              .
# 519   Population âgée de 10 ans et plus selon le niv...              .
# 520   Population âgée de 10 ans et plus selon le niv...              .
# 521   Population âgée de 10 ans et plus selon le niv...              .
# 522   Population âgée de 10 ans et plus selon le niv...              .
# 523   Population âgée de 10 ans et plus selon le niv...              .
# 524   Population âgée de 10 ans et plus selon le niv...              .
# 525   Population âgée de 10 ans et plus selon le niv...              .
# 526   Population âgée de 10 ans et plus selon le niv...              .
# 527   Population âgée de 10 ans et plus selon le niv...              .
# 528   Population âgée de 10 ans et plus selon le niv...              .
# 529   Population âgée de 10 ans et plus selon le niv...              .
# 530   Population âgée de 10 ans et plus selon le niv...              .
# 531   Population âgée de 10 ans et plus selon le niv...              .
# 532   Population âgée de 10 ans et plus selon le niv...              .
# 533   Population âgée de 10 ans et plus selon le niv...              .
# 534   Population âgée de 10 ans et plus selon le niv...              .
# 535   Population âgée de 10 ans et plus selon le niv...              .
# 536   Population âgée de 10 ans et plus selon le niv...              .
# 537   Population âgée de 10 ans et plus selon le niv...              .
# 538   Population âgée de 10 ans et plus selon le niv...              .
# 539   Population âgée de 10 ans et plus selon le niv...              .
# 540   Population âgée de 10 ans et plus selon le niv...              .
# 541   Population âgée de 10 ans et plus selon le niv...              .
# 542   Population âgée de 10 ans et plus selon le niv...              .
# 543   Population âgée de 10 ans et plus selon le niv...              .
# 544   Population âgée de 10 ans et plus selon le niv...              .
# 545   Population âgée de 10 ans et plus selon le niv...              .
# 546   Population âgée de 10 ans et plus selon le niv...              .
# 547   Population âgée de 10 ans et plus selon le niv...              .
# 548   Population âgée de 10 ans et plus selon le niv...              .
# 549   Population âgée de 10 ans et plus selon le niv...              .
# 550   Population âgée de 10 ans et plus selon le niv...              .
# 551   Population âgée de 10 ans et plus selon le niv...              .
# 552   Population âgée de 10 ans et plus selon le niv...              .
# 553   Population âgée de 10 ans et plus selon le niv...              .
# 554   Population âgée de 10 ans et plus selon le niv...              .
# 555   Population âgée de 10 ans et plus selon le niv...              .
# 556   Population âgée de 10 ans et plus selon le niv...              .
# 557   Population âgée de 10 ans et plus selon le niv...              .
# 558   Population âgée de 10 ans et plus selon le niv...              .
# 559   Population âgée de 10 ans et plus selon le niv...              .
# 560   Population âgée de 10 ans et plus selon le niv...              .
# 561   Population âgée de 10 ans et plus selon le niv...              .
# 562   Population âgée de 10 ans et plus selon le niv...              .
# 563   Population âgée de 10 ans et plus selon le niv...              .
# 564   Population âgée de 10 ans et plus selon le niv...              .
# 565   Population âgée de 10 ans et plus selon le niv...              .
# 566   Population âgée de 10 ans et plus selon le niv...              .
# 567   Population âgée de 10 ans et plus selon le niv...              .
# 568   Population âgée de 10 ans et plus selon le niv...              .
# 569   Population âgée de 10 ans et plus selon le niv...              .
# 570   Population âgée de 10 ans et plus selon le niv...              .
# 571   Population âgée de 10 ans et plus selon le niv...              .
# 572   Population âgée de 10 ans et plus selon le niv...              .
# 573   Population âgée de 10 ans et plus selon le niv...              .
# 574   Population âgée de 10 ans et plus selon le niv...              .
# 575   Population âgée de 10 ans et plus selon le niv...              .
# 576   Population âgée de 10 ans et plus selon le niv...              .
# 577   Population âgée de 10 ans et plus selon le niv...              .
# 578   Population âgée de 10 ans et plus selon le niv...              .
# 579   Population âgée de 10 ans et plus selon le niv...              .
# 580   Population âgée de 10 ans et plus selon le niv...              .
# 581   Population âgée de 10 ans et plus selon le niv...              .
# 582   Population âgée de 10 ans et plus selon le niv...              .
# 583   Population âgée de 10 ans et plus selon le niv...              .
# 584   Population âgée de 10 ans et plus selon le niv...              .
# 585   Population âgée de 10 ans et plus selon le niv...              .
# 586   Population âgée de 10 ans et plus selon le niv...              .
# 587   Population âgée de 10 ans et plus selon le niv...              .
# 588   Population âgée de 10 ans et plus selon le niv...              .
# 589   Population âgée de 10 ans et plus selon le niv...              .
# 590   Population âgée de 10 ans et plus selon le niv...              .
# 591   Population âgée de 10 ans et plus selon le niv...              .
# 592   Population âgée de 10 ans et plus selon le niv...              .
# 593   Population âgée de 10 ans et plus selon le niv...              .
# 594   Population âgée de 10 ans et plus selon le niv...              .
# 595   Population âgée de 10 ans et plus selon le niv...              .
# 596   Population âgée de 10 ans et plus selon le niv...              .
# 597   Population âgée de 10 ans et plus selon le niv...              .
# 598   Population âgée de 10 ans et plus selon le niv...              .
# 599   Population âgée de 10 ans et plus selon le niv...              .
# 600   Population âgée de 10 ans et plus selon le niv...              .
# 601   Population âgée de 10 ans et plus selon le niv...              .
# 602   Population âgée de 10 ans et plus selon le niv...              .
# ...
# 4784         %  T72-86
# 4785         %  T72-86
# 4786         %  T72-86
# 4787         %  T72-86
# 4788         %  T72-86
# 4789         %  T72-86
# 4790         %  T72-86
# 4791         %  T72-86
# 4792         %  T72-86
# 4793         %  T72-86
# 4794         %  T72-86
# 4795         %  T72-86
# 4796         %  T72-86
# 4797         %  T72-86
# 4798         %  T72-86
# 4799         %  T72-86
# 4800         %  T72-86
# 4801         %  T72-86
# 4802         %  T72-86
# 4803         %  T72-86
# 4804         %  T72-86
# 4805         %  T72-86
# 4806         %  T72-86
# 4807         %  T72-86
# 4808         %  T72-86
# 4809         %  T72-86
# 4810         %  T72-86
# 4811         %  T72-86
# 4812         %  T72-86
# 4813         %  T72-86
# 4814         %  T72-86
# 4815         %  T72-86
# 4816         %  T72-86
# 4817         %  T72-86
# 4818         %  T72-86
# 4819         %  T72-86
# 4820         %  T72-86
# 4821         %  T72-86
# 4822         %  T72-86
# 4823         %  T72-86
# 4824         %  T72-86
# 4825         %  T72-86
# 4826         %  T72-86
# 4827         %  T72-86
# 4828         %  T72-86
# 4829         %  T72-86
# 4830         %  T72-86
# 4831         %  T72-86
# 4832         %  T72-86
# 4833         %  T72-86
# 4834         %  T72-86
# 4835         %  T72-86
# 4836         %  T72-86
# 4837         %  T72-86
# 4838         %  T72-86
# 4839         %  T72-86
# 4840         %  T72-86
# 4841         %  T72-86
# 4842         %  T72-86
# 4843         %  T72-86
# 4844         %  T72-86
# 4845         %  T72-86
# 4846         %  T72-86
# 4847         %  T72-86
# 4848         %  T72-87
# 4849         %  T72-87
# 4850         %  T72-87
# 4851         %  T72-87
# 4852         %  T72-87
# 4853         %  T72-87
# 4854         %  T72-87
# 4855         %  T72-87
# 4856         %  T72-87
# 4857         %  T72-87
# 4858         %  T72-87
# 4859         %  T72-87
# 4860         %  T72-87
# 4861         %  T72-87
# 4862         %  T72-87
# 4863         %  T72-87
# 4864         %  T72-87
# 4865         %  T72-87
# 4866         %  T72-87
# 4867         %  T72-87
# 4868         %  T72-87
# 4869         %  T72-87
# 4870         %  T72-87
# 4871         %  T72-87
# 4872         %  T72-87
# 4873         %  T72-87
# 4874         %  T72-87
# 4875         %  T72-87
# 4876         %  T72-87
# 4877         %  T72-87
# 4878         %  T72-87
# 4879         %  T72-87
# 4880         %  T72-87
# 4881         %  T72-87
# 4882         %  T72-87
# 4883         %  T72-87
# 4884         %  T72-87
# 4885         %  T72-87
# 4886         %  T72-87
# 4887         %  T72-87
# 4888         %  T72-87
# 4889         %  T72-87
# 4890         %  T72-87
# 4891         %  T72-87
# 4892         %  T72-87
# 4893         %  T72-87
# 4894         %  T72-87
# 4895         %  T72-87
# 4896         %  T72-87
# 4897         %  T72-87
# 4898         %  T72-87
# 4899         %  T72-87
# 4900         %  T72-87
# 4901         %  T72-87
# 4902         %  T72-87
# 4903         %  T72-87
# 4904         %  T72-87
# 4905         %  T72-87
# 4906         %  T72-87
# 4907         %  T72-87
# 4908         %  T72-87
# 4909         %  T72-87
# 4910         %  T72-87
# 4911         %  T72-87
# 4912         %  T72-87
# 4913         %  T72-87
# 4914         %  T72-87
# 4915         %  T72-87
# 4916         %  T72-87
# 4917         %  T72-87
# 4918         %  T72-87
# 4919         %  T72-87
# 4920         %  T72-87
# 4921         %  T72-87
# 4922         %  T72-87
# 4923         %  T72-87
# 4924         %  T72-87
# 4925         %  T72-87
# 4926         %  T72-87
# 4927         %  T72-87
# 4928         %  T72-87
# 4929         %  T72-87
# 4930         %  T72-87
# 4931         %  T72-87
# 4932         %  T72-87
# 4933         %  T72-87
# 4934         %  T72-87
# 4935         %  T72-87
# 4936         %  T72-87
# 4937         %  T72-87
# 4938         %  T72-87
# 4939         %  T72-87
# 4940         %  T72-87
# 4941         %  T72-87
# 4942         %  T72-87
# 4943         %  T72-87
# 4944         %  T72-87
# 4945         %  T72-87
# 4946         %  T72-87
# 4947         %  T72-87
# 4948         %  T72-87
# 4949         %  T72-87
# 4950         %  T72-87
# 4951         %  T72-87
# 4952         %  T72-87
# 4953         %  T72-87
# 4954         %  T72-87
# 4955         %  T72-87
# 4956         %  T72-87
# 4957         %  T72-87
# 4958         %  T72-87
# 4959         %  T72-87
# 4960         %  T72-87
# 4961         %  T72-87
# 4962         %  T72-87
# 4963         %  T72-87
# 4964         %  T72-87
# 4965         %  T72-87
# 4966         %  T72-87
# 4967         %  T72-87
# 4968         %  T72-87
# 4969         %  T72-87
# 4970         %  T72-87
# 4971         %  T72-87
# 4972         %  T72-87
# 4973         %  T72-87
# 4974         %  T72-87
# 4975         %  T72-87
# 4976         %  T72-87
# 4977         %  T72-87
# 4978         %  T72-87
# 4979         %  T72-87
# 4980         %  T72-87
# 4981         %  T72-87
# 4982         %  T72-87
# 4983         %  T72-87
# 4984         %  T72-87
# 4985         %  T72-87
# 4986         %  T72-87
# 4987         %  T72-87
# 4988         %  T72-87
# 4989         %  T72-87
# 4990         %  T72-87
# 4991         %  T72-87
# 4992         %  T72-87
# 4993         %  T72-87
# 4994         %  T72-87
# 4995         %  T72-87
# 4996         %  T72-87
# 4997         %  T72-87
# 4998         %  T72-87
# 4999         %  T72-87
# 5000         %  T72-87
# 5001         %  T72-87
# 5002         %  T72-87
# 5003         %  T72-87
# 5004         %  T72-87
# 5005         %  T72-87
# 5006         %  T72-87
# 5007         %  T72-87
# 5008         %  T72-87
# 5009         %  T72-87
# 5010         %  T72-87
# 5011         %  T72-87
# 5012         %  T72-87
# 5013         %  T72-87
# 5014         %  T72-87
# 5015         %  T72-87
# 5016         %  T72-87
# 5017         %  T72-87
# 5018         %  T72-87
# 5019         %  T72-87
# 5020         %  T72-87
# 5021         %  T72-87
# 5022         %  T72-87
# 5023         %  T72-87
# 5024         %  T72-87
# 5025         %  T72-87
# 5026         %  T72-87
# 5027         %  T72-87
# 5028         %  T72-87
# 5029         %  T72-87
# 5030         %  T72-87
# 5031         %  T72-87
# 5032         %  T72-87
# 5033         %  T72-87
# 5034         %  T72-87
# 5035         %  T72-87
# 5036         %  T72-87
# 5037         %  T72-87
# 5038         %  T72-87
# 5039         %  T72-87
# 5040         %  T72-88
# 5041         %  T72-88
# 5042         %  T72-88
# 5043         %  T72-88
# 5044         %  T72-88
# 5045         %  T72-88
# 5046         %  T72-88
# 5047         %  T72-88
# 5048         %  T72-88
# 5049         %  T72-88
# 5050         %  T72-88
# 5051         %  T72-88
# 5052         %  T72-88
# 5053         %  T72-88
# 5054         %  T72-88
# 5055         %  T72-88
# 5056         %  T72-88
# 5057         %  T72-88
# 5058         %  T72-88
# 5059         %  T72-88
# 5060         %  T72-88
# 5061         %  T72-88
# 5062         %  T72-88
# 5063         %  T72-88
# 5064         %  T72-88
# 5065         %  T72-88
# 5066         %  T72-88
# 5067         %  T72-88
# 5068         %  T72-88
# 5069         %  T72-88
# 5070         %  T72-88
# 5071         %  T72-88
# 5072         %  T72-88
# 5073         %  T72-88
# 5074         %  T72-88
# 5075         %  T72-88
# 5076         %  T72-88
# 5077         %  T72-88
# 5078         %  T72-88
# 5079         %  T72-88
# 5080         %  T72-88
# 5081         %  T72-88
# 5082         %  T72-88
# 5083         %  T72-88
# 5084         %  T72-88
# 5085         %  T72-88
# 5086         %  T72-88
# 5087         %  T72-88
# 5088         %  T72-88
# 5089         %  T72-88
# 5090         %  T72-88
# 5091         %  T72-88
# 5092         %  T72-88
# 5093         %  T72-88
# 5094         %  T72-88
# 5095         %  T72-88
# 5096         %  T72-88
# 5097         %  T72-88
# 5098         %  T72-88
# 5099         %  T72-88
# 5100         %  T72-88
# 5101         %  T72-88
# 5102         %  T72-88
# 5103         %  T72-88
# 5104         %  T72-88
# 5105         %  T72-88
# 5106         %  T72-88
# 5107         %  T72-88
# 5108         %  T72-88
# 5109         %  T72-88
# 5110         %  T72-88
# 5111         %  T72-88
# 5112         %  T72-88
# 5113         %  T72-88
# 5114         %  T72-88
# 5115         %  T72-88
# 5116         %  T72-88
# 5117         %  T72-88
# 5118         %  T72-88
# 5119         %  T72-88
# 5120         %  T72-88
# 5121         %  T72-88
# 5122         %  T72-88
# 5123         %  T72-88
# 5124         %  T72-88
# 5125         %  T72-88
# 5126         %  T72-88
# 5127         %  T72-88
# 5128         %  T72-88
# 5129         %  T72-88
# 5130         %  T72-88
# 5131         %  T72-88
# 5132         %  T72-88
# 5133         %  T72-88
# 5134         %  T72-88
# 5135         %  T72-88
# 5136         %  T72-88
# 5137         %  T72-88
# 5138         %  T72-88
# 5139         %  T72-88
# 5140         %  T72-88
# 5141         %  T72-88
# 5142         %  T72-88
# 5143         %  T72-88
# 5144         %  T72-88
# 5145         %  T72-88
# 5146         %  T72-88
# 5147         %  T72-88
# 5148         %  T72-88
# 5149         %  T72-88
# 5150         %  T72-88
# 5151         %  T72-88
# 5152         %  T72-88
# 5153         %  T72-88
# 5154         %  T72-88
# 5155         %  T72-88
# 5156         %  T72-88
# 5157         %  T72-88
# 5158         %  T72-88
# 5159         %  T72-88
# 5160         %  T72-88
# 5161         %  T72-88
# 5162         %  T72-88
# 5163         %  T72-88
# 5164         %  T72-88
# 5165         %  T72-88
# 5166         %  T72-88
# 5167         %  T72-88
# 5168         %  T72-88
# 5169         %  T72-88
# 5170         %  T72-88
# 5171         %  T72-88
# 5172         %  T72-88
# 5173         %  T72-88
# 5174         %  T72-88
# 5175         %  T72-88
# 5176         %  T72-88
# 5177         %  T72-88
# 5178         %  T72-88
# 5179         %  T72-88
# 5180         %  T72-88
# 5181         %  T72-88
# 5182         %  T72-88
# 5183         %  T72-88
# 5184         %  T72-88
# 5185         %  T72-88
# 5186         %  T72-88
# 5187         %  T72-88
# 5188         %  T72-88
# 5189         %  T72-88
# 5190         %  T72-88
# 5191         %  T72-88
# 5192         %  T72-88
# 5193         %  T72-88
# 5194         %  T72-88
# 5195         %  T72-88
# 5196         %  T72-88
# 5197         %  T72-88
# 5198         %  T72-88
# 5199         %  T72-88
# 5200         %  T72-88
# 5201         %  T72-88
# 5202         %  T72-88
# 5203         %  T72-88
# 5204         %  T72-88
# 5205         %  T72-88
# 5206         %  T72-88
# 5207         %  T72-88
# 5208         %  T72-88
# 5209         %  T72-88
# 5210         %  T72-88
# 5211         %  T72-88
# 5212         %  T72-88
# 5213         %  T72-88
# 5214         %  T72-88
# 5215         %  T72-88
# 5216         %  T72-88
# 5217         %  T72-88
# 5218         %  T72-88
# 5219         %  T72-88
# 5220         %  T72-88
# 5221         %  T72-88
# 5222         %  T72-88
# 5223         %  T72-88
# 5224         %  T72-88
# 5225         %  T72-88
# 5226         %  T72-88
# 5227         %  T72-88
# 5228         %  T72-88
# 5229         %  T72-88
# 5230         %  T72-88
# 5231         %  T72-88
# 5232         %  T72-89
# 5233         %  T72-89
# 5234         %  T72-89
# 5235         %  T72-89
# 5236         %  T72-89
# 5237         %  T72-89
# 5238         %  T72-89
# 5239         %  T72-89
# 5240         %  T72-89
# 5241         %  T72-89
# 5242         %  T72-89
# 5243         %  T72-89
# 5244         %  T72-89
# 5245         %  T72-89
# 5246         %  T72-89
# 5247         %  T72-89
# 5248         %  T72-89
# 5249         %  T72-89
# 5250         %  T72-89
# 5251         %  T72-89
# 5252         %  T72-89
# 5253         %  T72-89
# 5254         %  T72-89
# 5255         %  T72-89
# 5256         %  T72-89
# 5257         %  T72-89
# 5258         %  T72-89
# 5259         %  T72-89
# 5260         %  T72-89
# 5261         %  T72-89
# 5262         %  T72-89
# 5263         %  T72-89
# 5264         %  T72-89
# 5265         %  T72-89
# 5266         %  T72-89
# 5267         %  T72-89
# 5268         %  T72-89
# 5269         %  T72-89
# 5270         %  T72-89
# 5271         %  T72-89
# 5272         %  T72-89
# 5273         %  T72-89
# 5274         %  T72-89
# 5275         %  T72-89
# 5276         %  T72-89
# 5277         %  T72-89
# 5278         %  T72-89
# 5279         %  T72-89
# 5280         %  T72-89
# 5281         %  T72-89
# 5282         %  T72-89
# 5283         %  T72-89
# 5284         %  T72-89
# 5285         %  T72-89
# 5286         %  T72-89
# 5287         %  T72-89
# 5288         %  T72-89
# 5289         %  T72-89
# 5290         %  T72-89
# 5291         %  T72-89
# 5292         %  T72-89
# 5293         %  T72-89
# 5294         %  T72-89
# 5295         %  T72-89
# 5296         %  T72-89
# 5297         %  T72-89
# 5298         %  T72-89
# 5299         %  T72-89
# 5300         %  T72-89
# 5301         %  T72-89
# 5302         %  T72-89
# 5303         %  T72-89
# 5304         %  T72-89
# 5305         %  T72-89
# 5306         %  T72-89
# 5307         %  T72-89
# 5308         %  T72-89
# 5309         %  T72-89
# 5310         %  T72-89
# 5311         %  T72-89
# 5312         %  T72-89
# 5313         %  T72-89
# 5314         %  T72-89
# 5315         %  T72-89
# 5316         %  T72-89
# 5317         %  T72-89
# 5318         %  T72-89
# 5319         %  T72-89
# 5320         %  T72-89
# 5321         %  T72-89
# 5322         %  T72-89
# 5323         %  T72-89
# 5324         %  T72-89
# 5325         %  T72-89
# 5326         %  T72-89
# 5327         %  T72-89
# 5328         %  T72-89
# 5329         %  T72-89
# 5330         %  T72-89
# 5331         %  T72-89
# 5332         %  T72-89
# 5333         %  T72-89
# 5334         %  T72-89
# 5335         %  T72-89
# 5336         %  T72-89
# 5337         %  T72-89
# 5338         %  T72-89
# 5339         %  T72-89
# 5340         %  T72-89
# 5341         %  T72-89
# 5342         %  T72-89
# 5343         %  T72-89
# 5344         %  T72-89
# 5345         %  T72-89
# 5346         %  T72-89
# 5347         %  T72-89
# 5348         %  T72-89
# 5349         %  T72-89
# 5350         %  T72-89
# 5351         %  T72-89
# 5352         %  T72-89
# 5353         %  T72-89
# 5354         %  T72-89
# 5355         %  T72-89
# 5356         %  T72-89
# 5357         %  T72-89
# 5358         %  T72-89
# 5359         %  T72-89
# 5360         %  T72-89
# 5361         %  T72-89
# 5362         %  T72-89
# 5363         %  T72-89
# 5364         %  T72-89
# 5365         %  T72-89
# 5366         %  T72-89
# 5367         %  T72-89
# 5368         %  T72-89
# 5369         %  T72-89
# 5370         %  T72-89
# 5371         %  T72-89
# 5372         %  T72-89
# 5373         %  T72-89
# 5374         %  T72-89
# 5375         %  T72-89
# 5376         %  T72-89
# 5377         %  T72-89
# 5378         %  T72-89
# 5379         %  T72-89
# 5380         %  T72-89
# 5381         %  T72-89
# 5382         %  T72-89
# 5383         %  T72-89
# 5384         %  T72-89
# 5385         %  T72-89
# 5386         %  T72-89
# 5387         %  T72-89
# 5388         %  T72-89
# 5389         %  T72-89
# 5390         %  T72-89
# 5391         %  T72-89
# 5392         %  T72-89
# 5393         %  T72-89
# 5394         %  T72-89
# 5395         %  T72-89
# 5396         %  T72-89
# 5397         %  T72-89
# 5398         %  T72-89
# 5399         %  T72-89
# 5400         %  T72-89
# 5401         %  T72-89
# 5402         %  T72-89
# 5403         %  T72-89
# 5404         %  T72-89
# 5405         %  T72-89
# 5406         %  T72-89
# 5407         %  T72-89
# 5408         %  T72-89
# 5409         %  T72-89
# 5410         %  T72-89
# 5411         %  T72-89
# 5412         %  T72-89
# 5413         %  T72-89
# 5414         %  T72-89
# 5415         %  T72-89
# 5416         %  T72-89
# 5417         %  T72-89
# 5418         %  T72-89
# 5419         %  T72-89
# 5420         %  T72-89
# 5421         %  T72-89
# 5422         %  T72-89
# 5423         %  T72-89
